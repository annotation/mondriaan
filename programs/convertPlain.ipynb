# %% [markdown]
# # Convert from TEI to TF
#
# We convert Mondriaan TEI to TF.
#
# This notebook is bare, no explanations, nu illustrations, no checks.
# For more documentation, try any of the following variants:
#
# * *convertExpress* : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * [convertDetails](convertDetails.ipynb): run from Python with full control

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.advanced.helpers import dm

# %%
ORG = "annotation"
REPO = "mondriaan"

# %% [markdown]
# ### Step 1: Check

# %%
Tei = TEI(verbose=-1, tei=0, tf="0.8.12pre")

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/github/annotation/mondriaan/tei/2023-05-24 => ~/github/annotation/mondriaan/report/2023-05-24
# Processing instructions are treated
# XML validation will be performed
# Section model I
# Start folder proeftuin:
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090216y_IONG_1303.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090216y_IONG_1303.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    1 MD           letter       19090216y_IONG_1303.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090407y_IONG_1739.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090407y_IONG_1739.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    2 MD           letter       19090407y_IONG_1739.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090421y_IONG_1304.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090421y_IONG_1304.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    3 MD           letter       19090421y_IONG_1304.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090426y_IONG_1738.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090426y_IONG_1738.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    4 MD           letter       19090426y_IONG_1738.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090513y_IONG_1293.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090513y_IONG_1293.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    5 MD           letter       19090513y_IONG_1293.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090624_IONG_1294.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090624_IONG_1294.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    6 MD           letter       19090624_IONG_1294.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090807y_IONG_1296.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090807y_IONG_1296.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    7 MD           letter       19090807y_IONG_1296.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090824y_KNAP_1747.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090824y_KNAP_1747.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    8 MD           letter       19090824y_KNAP_1747.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090905y_IONG_1295.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19090905y_IONG_1295.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#    9 MD           letter       19090905y_IONG_1295.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/190909XX_QUER_1654.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/190909XX_QUER_1654.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   10 MD           letter       190909XX_QUER_1654.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091024_SPOO_0016.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091024_SPOO_0016.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   11 MD           letter       19091024_SPOO_0016.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091024y_IONG_1297.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091024y_IONG_1297.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   12 MD           letter       19091024y_IONG_1297.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091025y_IONG_1298.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19091025y_IONG_1298.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   13 MD           letter       19091025y_IONG_1298.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19100131_SAAL_ARNO_0018.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/proeftuin/19100131_SAAL_ARNO_0018.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   14 MD           letter       19100131_SAAL_ARNO_0018.xml
#
# End   folder proeftuin
# Start folder backmatter:
# ~/github/annotation/mondriaan/tei/2023-05-24/backmatter/artwork.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/backmatter/artwork.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   15 TEI          artworks     artwork.xml
# ~/github/annotation/mondriaan/tei/2023-05-24/backmatter/biblio.xml: adaptation triggerRe=re.compile('<\\?editem\\b[^>]*?adaptation=[\'"]([^\'"]+)[\'"]')
# ~/github/annotation/mondriaan/tei/2023-05-24/backmatter/biblio.xml: template triggerRe=re.compile('<\\?editem\\b[^>]*?template=[\'"]([^\'"]+)[\'"]')
#   16 TEI          biblio       biblio.xml
#
# End   folder backmatter
# Validating MD files ...
# Validating TEI files ...
# Elapsed time 637+291=928 milliseconds
#
# 0 info line(s) written to ~/github/annotation/mondriaan/report/2023-05-24/elements.txt
# 178 validation error(s) in 178 file(s) written to ~/github/annotation/mondriaan/report/2023-05-24/errors.txt
# 0 processing instructions encountered.
# 0 tags of which 0 with multiple namespaces written to ~/github/annotation/mondriaan/report/2023-05-24/namespaces.txt
# False

# %% [markdown]
# ### Step 2: Convert

# %%
Tei.good = True
Tei.task(convert=True)
# Out:
# TEI to TF converting: ~/github/annotation/mondriaan/tei/2023-05-24 => ~/github/annotation/mondriaan/tf/0.8.12pre
# Page model II with pb elements at the top of the page
# Processing instructions are treated
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/annotation/mondriaan/tf/0.8.12pre
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    folder, file, chunk
#    |   SECTION   FEATURES: folder, file, chunk
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       ch
#    |     0.00s OK
#    |     0.00s Following director...
# Start folder proeftuin:
#    1 MD           letter       19090216y_IONG_1303.xml
#    2 MD           letter       19090407y_IONG_1739.xml
#    3 MD           letter       19090421y_IONG_1304.xml
#    4 MD           letter       19090426y_IONG_1738.xml
#    5 MD           letter       19090513y_IONG_1293.xml
#    6 MD           letter       19090624_IONG_1294.xml
#    7 MD           letter       19090807y_IONG_1296.xml
#    8 MD           letter       19090824y_KNAP_1747.xml
#    9 MD           letter       19090905y_IONG_1295.xml
#   10 MD           letter       190909XX_QUER_1654.xml
#   11 MD           letter       19091024_SPOO_0016.xml
#   12 MD           letter       19091024y_IONG_1297.xml
#   13 MD           letter       19091025y_IONG_1298.xml
#   14 MD           letter       19100131_SAAL_ARNO_0018.xml
#
# End   folder proeftuin
# Start folder backmatter:
#   15 artwork      artworks     artwork.xml
#   16 TEI          biblio       biblio.xml
#
# End   folder backmatter
#
# source reading done
#    |     0.28s "delete" actions: 0
#    |     0.28s "edge" actions: 10439
#    |     0.28s "feature" actions: 145994
#    |     0.28s "node" actions: 15686
#    |     0.28s "resume" actions: 0
#    |     0.28s "slot" actions: 78268
#    |     0.28s "terminate" actions: 15702
#    |         15 x "?editem" node
#    |          2 x "abbr" node
#    |          1 x "accMat" node
#    |          8 x "add" node
#    |          6 x "addrLine" node
#    |          4 x "address" node
#    |         28 x "altIdentifier" node
#    |         10 x "artwork" node
#    |          1 x "artworks" node
#    |          1 x "author" node
#    |        109 x "bibl" node
#    |          1 x "biblio" node
#    |         16 x "body" node
#    |         43 x "catRef" node
#    |        168 x "change" node
#    |      78268 x "char" node  = slot type
#    |         15 x "choice" node
#    |        222 x "chunk" node
#    |          1 x "classDecl" node
#    |         30 x "closer" node
#    |         28 x "correspAction" node
#    |         14 x "correspDesc" node
#    |         14 x "country" node
#    |         26 x "date" node
#    |          6 x "dateline" node
#    |         14 x "decoDesc" node
#    |         14 x "decoNote" node
#    |          9 x "del" node
#    |         10 x "desc" node
#    |         31 x "div" node
#    |         28 x "editor" node
#    |          1 x "encodingDesc" node
#    |          2 x "expan" node
#    |         14 x "facsimile" node
#    |         16 x "file" node
#    |         16 x "fileDesc" node
#    |          2 x "folder" node
#    |         73 x "graphic" node
#    |         14 x "head" node
#    |         65 x "hi" node
#    |         42 x "idno" node
#    |         14 x "institution" node
#    |          5 x "lb" node
#    |         14 x "letter" node
#    |         46 x "listAnnotation" node
#    |          2 x "listBibl" node
#    |          1 x "listObject" node
#    |         20 x "measure" node
#    |         14 x "msDesc" node
#    |         14 x "msIdentifier" node
#    |         28 x "name" node
#    |        105 x "note" node
#    |         14 x "objectDesc" node
#    |         28 x "opener" node
#    |         11 x "orig" node
#    |         96 x "p" node
#    |         51 x "page" node
#    |         14 x "physDesc" node
#    |         14 x "placeName" node
#    |          2 x "postmark" node
#    |          6 x "postscript" node
#    |         14 x "profileDesc" node
#    |         82 x "ptr" node
#    |         16 x "publicationStmt" node
#    |         67 x "ref" node
#    |         11 x "reg" node
#    |         10 x "relation" node
#    |         14 x "revisionDesc" node
#    |        190 x "rs" node
#    |         56 x "salute" node
#    |         14 x "settlement" node
#    |         30 x "signed" node
#    |         16 x "sourceDesc" node
#    |          9 x "space" node
#    |         14 x "sponsor" node
#    |         14 x "standOff" node
#    |         49 x "surface" node
#    |          4 x "taxonomy" node
#    |         16 x "teiHeader" node
#    |         16 x "text" node
#    |        159 x "title" node
#    |         16 x "titleStmt" node
#    |          4 x "unclear" node
#    |      13232 x "word" node
#    |         14 x "zone" node
#    |      93954 nodes of all types
#    |     0.30s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.00s No slot sorting needed
#    |     0.01s Sorting 15 nodes of type "?editem"
#    |     0.01s Sorting 2 nodes of type "abbr"
#    |     0.01s Sorting 1 nodes of type "accMat"
#    |     0.01s Sorting 8 nodes of type "add"
#    |     0.01s Sorting 6 nodes of type "addrLine"
#    |     0.01s Sorting 4 nodes of type "address"
#    |     0.01s Sorting 28 nodes of type "altIdentifier"
#    |     0.01s Sorting 10 nodes of type "artwork"
#    |     0.01s Sorting 1 nodes of type "artworks"
#    |     0.01s Sorting 1 nodes of type "author"
#    |     0.01s Sorting 109 nodes of type "bibl"
#    |     0.01s Sorting 1 nodes of type "biblio"
#    |     0.01s Sorting 16 nodes of type "body"
#    |     0.01s Sorting 43 nodes of type "catRef"
#    |     0.01s Sorting 168 nodes of type "change"
#    |     0.02s Sorting 15 nodes of type "choice"
#    |     0.02s Sorting 222 nodes of type "chunk"
#    |     0.02s Sorting 1 nodes of type "classDecl"
#    |     0.02s Sorting 30 nodes of type "closer"
#    |     0.02s Sorting 28 nodes of type "correspAction"
#    |     0.02s Sorting 14 nodes of type "correspDesc"
#    |     0.02s Sorting 14 nodes of type "country"
#    |     0.02s Sorting 26 nodes of type "date"
#    |     0.02s Sorting 6 nodes of type "dateline"
#    |     0.02s Sorting 14 nodes of type "decoDesc"
#    |     0.02s Sorting 14 nodes of type "decoNote"
#    |     0.02s Sorting 9 nodes of type "del"
#    |     0.02s Sorting 10 nodes of type "desc"
#    |     0.02s Sorting 31 nodes of type "div"
#    |     0.02s Sorting 28 nodes of type "editor"
#    |     0.03s Sorting 1 nodes of type "encodingDesc"
#    |     0.03s Sorting 2 nodes of type "expan"
#    |     0.03s Sorting 14 nodes of type "facsimile"
#    |     0.03s Sorting 16 nodes of type "file"
#    |     0.03s Sorting 16 nodes of type "fileDesc"
#    |     0.03s Sorting 2 nodes of type "folder"
#    |     0.03s Sorting 73 nodes of type "graphic"
#    |     0.03s Sorting 14 nodes of type "head"
#    |     0.03s Sorting 65 nodes of type "hi"
#    |     0.03s Sorting 42 nodes of type "idno"
#    |     0.03s Sorting 14 nodes of type "institution"
#    |     0.03s Sorting 5 nodes of type "lb"
#    |     0.03s Sorting 14 nodes of type "letter"
#    |     0.04s Sorting 46 nodes of type "listAnnotation"
#    |     0.04s Sorting 2 nodes of type "listBibl"
#    |     0.04s Sorting 1 nodes of type "listObject"
#    |     0.04s Sorting 20 nodes of type "measure"
#    |     0.04s Sorting 14 nodes of type "msDesc"
#    |     0.04s Sorting 14 nodes of type "msIdentifier"
#    |     0.04s Sorting 28 nodes of type "name"
#    |     0.04s Sorting 105 nodes of type "note"
#    |     0.04s Sorting 14 nodes of type "objectDesc"
#    |     0.04s Sorting 28 nodes of type "opener"
#    |     0.04s Sorting 11 nodes of type "orig"
#    |     0.04s Sorting 96 nodes of type "p"
#    |     0.05s Sorting 51 nodes of type "page"
#    |     0.05s Sorting 14 nodes of type "physDesc"
#    |     0.05s Sorting 14 nodes of type "placeName"
#    |     0.05s Sorting 2 nodes of type "postmark"
#    |     0.05s Sorting 6 nodes of type "postscript"
#    |     0.05s Sorting 14 nodes of type "profileDesc"
#    |     0.05s Sorting 82 nodes of type "ptr"
#    |     0.05s Sorting 16 nodes of type "publicationStmt"
#    |     0.05s Sorting 67 nodes of type "ref"
#    |     0.05s Sorting 11 nodes of type "reg"
#    |     0.05s Sorting 10 nodes of type "relation"
#    |     0.05s Sorting 14 nodes of type "revisionDesc"
#    |     0.05s Sorting 190 nodes of type "rs"
#    |     0.05s Sorting 56 nodes of type "salute"
#    |     0.05s Sorting 14 nodes of type "settlement"
#    |     0.05s Sorting 30 nodes of type "signed"
#    |     0.05s Sorting 16 nodes of type "sourceDesc"
#    |     0.05s Sorting 9 nodes of type "space"
#    |     0.05s Sorting 14 nodes of type "sponsor"
#    |     0.06s Sorting 14 nodes of type "standOff"
#    |     0.06s Sorting 49 nodes of type "surface"
#    |     0.06s Sorting 4 nodes of type "taxonomy"
#    |     0.06s Sorting 16 nodes of type "teiHeader"
#    |     0.06s Sorting 16 nodes of type "text"
#    |     0.06s Sorting 159 nodes of type "title"
#    |     0.06s Sorting 16 nodes of type "titleStmt"
#    |     0.06s Sorting 4 nodes of type "unclear"
#    |     0.06s Sorting 13232 nodes of type "word"
#    |     0.07s Sorting 14 nodes of type "zone"
#    |     0.07s Max node = 93954
#    |     0.07s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "adaptation" with 14 nodes
#    |      |   node feature "after" with 13232 nodes
#    |      |   node feature "artmondriaanref" with 18 nodes
#    |      |   node feature "ch" with 78268 nodes
#    |      |   node feature "chunk" with 222 nodes
#    |      |   node feature "commodity" with 20 nodes
#    |      |   node feature "corresp" with 10 nodes
#    |      |   node feature "correspondent" with 14 nodes
#    |      |   node feature "country" with 14 nodes
#    |      |   node feature "dim" with 9 nodes
#    |      |   node feature "empty" with 554 nodes
#    |      |   node feature "exhibitionref" with 15 nodes
#    |      |   node feature "extraspace" with 1005 nodes
#    |      |   node feature "f" with 46 nodes
#    |      |   node feature "facs" with 48 nodes
#    |      |   node feature "file" with 32 nodes
#    |      |   node feature "folder" with 2 nodes
#    |      |   node feature "form" with 14 nodes
#    |      |   node feature "id" with 439 nodes
#    |      |   node feature "institution" with 14 nodes
#    |      |   node feature "is_meta" with 11629 nodes
#    |      |   node feature "is_note" with 26108 nodes
#    |      |   node feature "key" with 34 nodes
#    |      |   node feature "lang" with 84 nodes
#    |      |   node feature "letterid" with 14 nodes
#    |      |   node feature "level" with 143 nodes
#    |      |   node feature "location" with 14 nodes
#    |      |   node feature "msid" with 14 nodes
#    |      |   node feature "n" with 281 nodes
#    |      |   node feature "name" with 10 nodes
#    |      |   node feature "period" with 14 nodes
#    |      |   node feature "periodlong" with 14 nodes
#    |      |   node feature "personref" with 112 nodes
#    |      |   node feature "place" with 3 nodes
#    |      |   node feature "quantity" with 29 nodes
#    |      |   node feature "reason" with 2 nodes
#    |      |   node feature "ref" with 122 nodes
#    |      |   node feature "rend" with 84 nodes
#    |      |   node feature "rend_above" with 8 nodes
#    |      |   node feature "rend_blockletter" with 34 nodes
#    |      |   node feature "rend_bold" with 2 nodes
#    |      |   node feature "rend_center" with 7 nodes
#    |      |   node feature "rend_indent" with 170 nodes
#    |      |   node feature "rend_italics" with 553 nodes
#    |      |   node feature "rend_norend" with 4 nodes
#    |      |   node feature "rend_overwritten" with 2 nodes
#    |      |   node feature "rend_right" with 6 nodes
#    |      |   node feature "rend_right_underline" with 6 nodes
#    |      |   node feature "rend_spaced" with 38 nodes
#    |      |   node feature "rend_super" with 12 nodes
#    |      |   node feature "rend_super_underline" with 1 node
#    |      |   node feature "rend_super_underline2" with 2 nodes
#    |      |   node feature "rend_underline" with 212 nodes
#    |      |   node feature "rend_underline2" with 5 nodes
#    |      |   node feature "rend_upsidedown" with 90 nodes
#    |      |   node feature "scheme" with 43 nodes
#    |      |   node feature "sender" with 14 nodes
#    |      |   node feature "source" with 10 nodes
#    |      |   node feature "str" with 13232 nodes
#    |      |   node feature "target" with 192 nodes
#    |      |   node feature "template" with 15 nodes
#    |      |   node feature "type" with 416 nodes
#    |      |   node feature "unit" with 29 nodes
#    |      |   node feature "url" with 73 nodes
#    |      |   node feature "when" with 14 nodes
#    |      |   node feature "who" with 127 nodes
#    |      |   edge feature "parent" with 2072 start nodes
#    |      |   edge feature "sibling" with 1233 start nodes
#    |     0.04s OK
#   0.43s Features ready to write
#   0.00s Exporting 67 node and 3 edge and 1 config features to ~/github/annotation/mondriaan/tf/0.8.12pre:
#   0.00s VALIDATING oslots feature
#   0.00s VALIDATING oslots feature
#   0.00s maxSlot=      78268
#   0.01s maxNode=      93954
#   0.01s OK: oslots is valid
#    |     0.00s T adaptation           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T after                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T artmondriaanref      to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.03s T ch                   to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T chunk                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T commodity            to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T corresp              to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T correspondent        to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T country              to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T dim                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T empty                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T exhibitionref        to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T extraspace           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T f                    to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T facs                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T file                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T folder               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T form                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T id                   to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T institution          to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T is_meta              to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.01s T is_note              to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T key                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T lang                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T letterid             to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T level                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T location             to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T msid                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T n                    to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T name                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.01s T otype                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T period               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T periodlong           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T personref            to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T place                to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T quantity             to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T reason               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T ref                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_above           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_blockletter     to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_bold            to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_center          to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_indent          to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_italics         to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_norend          to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_overwritten     to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_right           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_right_underline to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_spaced          to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_super           to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_super_underline to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_super_underline2 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_underline       to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_underline2      to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T rend_upsidedown      to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T scheme               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T sender               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T source               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.01s T str                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T target               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T template             to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T type                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T unit                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T url                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T when                 to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T who                  to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.04s T oslots               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s T parent               to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.01s T sibling              to ~/github/annotation/mondriaan/tf/0.8.12pre
#    |     0.00s M otext                to ~/github/annotation/mondriaan/tf/0.8.12pre
#   0.17s Exported 67 node features and 3 edge features and 1 config features to ~/github/annotation/mondriaan/tf/0.8.12pre
# True

# %% [markdown]
# ### Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and precomputations are performed.
# Next time the loading will be much quicker.

# %%
Tei.task(load=True)
# Out:
# True

# %% [markdown]
# ### Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# ### Step 5: Add tokens and sentences

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone", hoist=globals())
NLP = NLPipeline(lang="en", verbose=0, write=True)
NLP.loadApp(Apre)

(text, positions) = NLP.task(plaintext=True)
(tokens, sentences) = NLP.task(lingo=True, text=text)
newVersion = NLP.task(
    ingest=True,
    positions=positions,
    tokens=tokens,
    sentences=sentences,
)
Tei.task(apptoken=True)
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.12pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.16</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.12pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>2</td>
#     <td>39134.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>biblio</th>
#     <td>1</td>
#     <td>13652.00</td>
#     <td>17</td>
# </tr>
#
# <tr>
#     <th>listBibl</th>
#     <td>2</td>
#     <td>6722.50</td>
#     <td>17</td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>16</td>
#     <td>4891.75</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>4455.07</td>
#     <td>80</td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>16</td>
#     <td>2876.00</td>
#     <td>59</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>16</td>
#     <td>2876.00</td>
#     <td>59</td>
# </tr>
#
# <tr>
#     <th>artworks</th>
#     <td>1</td>
#     <td>2245.00</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>listObject</th>
#     <td>1</td>
#     <td>2035.00</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>14</td>
#     <td>1570.86</td>
#     <td>28</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>31</td>
#     <td>1417.84</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>51</td>
#     <td>544.31</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>46</td>
#     <td>478.09</td>
#     <td>28</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>424.07</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>222</td>
#     <td>352.50</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>16</td>
#     <td>629.50</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>96</td>
#     <td>296.83</td>
#     <td>36</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>250.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>105</td>
#     <td>215.06</td>
#     <td>29</td>
# </tr>
#
# <tr>
#     <th>artwork</th>
#     <td>10</td>
#     <td>195.40</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>16</td>
#     <td>193.12</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>109</td>
#     <td>124.39</td>
#     <td>17</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>16</td>
#     <td>109.94</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>16</td>
#     <td>80.75</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>76.93</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>159</td>
#     <td>53.59</td>
#     <td>11</td>
# </tr>
#
# <tr>
#     <th>desc</th>
#     <td>10</td>
#     <td>51.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>30</td>
#     <td>50.63</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>4</td>
#     <td>42.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>35.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>168</td>
#     <td>35.34</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>1</td>
#     <td>24.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>24.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>26</td>
#     <td>20.35</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>20.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>6</td>
#     <td>19.17</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>67</td>
#     <td>19.04</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>14</td>
#     <td>19.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>6</td>
#     <td>15.83</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>15.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>28</td>
#     <td>14.96</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>56</td>
#     <td>21.62</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>190</td>
#     <td>13.74</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>catRef</th>
#     <td>43</td>
#     <td>13.23</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>13.02</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>12.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>11.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>expan</th>
#     <td>2</td>
#     <td>10.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>9.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>65</td>
#     <td>8.57</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>30</td>
#     <td>8.53</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>classDecl</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>encodingDesc</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>7.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>abbr</th>
#     <td>2</td>
#     <td>7.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>7.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>6.86</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>15</td>
#     <td>5.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>13232</td>
#     <td>4.69</td>
#     <td>79</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>4.56</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>14</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>49</td>
#     <td>2.92</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>16</td>
#     <td>2.44</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>taxonomy</th>
#     <td>4</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>11</td>
#     <td>1.91</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>11</td>
#     <td>1.82</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>?editem</th>
#     <td>15</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>73</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>5</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>measure</th>
#     <td>20</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 28 artwork-ms<br>
# Input data has version 0.8.12pre
# Compute element boundaries
#   1591 start postions
#   1850 end postions
# Input data has version 0.8.12pre
# Compute element boundaries
#   1591 start postions
#   1850 end postions
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 277 empty slots
#    |   recorded flow main       with 168540 items
#    |   recorded flow del        with    153 items
#    |   recorded flow note       with  68245 items
#    |   recorded flow orig       with     95 items
#   0.16s Done. Generated text and positions written to ~/github/annotation/mondriaan/_temp/txt/plain.txt
# Input data has version 0.8.12pre
# Compute element boundaries
#   1591 start postions
#   1850 end postions
#   0.00s Using NLP pipeline Spacy (en) ...
#   3.89s Atomic tokens written to ~/github/annotation/mondriaan/_temp/txt/tokens.tsv
#   3.90s Sentences written to ~/github/annotation/mondriaan/_temp/txt/sentences.tsv
#   3.90s NLP done
# Input data has version 0.8.12pre
# Compute element boundaries
#   1591 start postions
#   1850 end postions
#   0.00s Ingesting tokens, and sentences into the dataset ...
#    |     4.10s Mapping NLP data to nodes and features ...
#    |      |    -0.00s generating t-nodes with features str, after, empty
#    |      |      |     0.00s 17101 t nodes have values assigned for str, after
#    |      |      |     0.00s 0 empty slots are properly contained in a token
#    |      |      |     0.00s 84 space slots have split into chars
#    |      |      |     0.00s 2074 slots have split around an element boundary
#    |      |      |     0.00s  9110x Items contained in extra generated text
#    |      |     0.06s 16906 tokens
#    |      |     0.06s 17101 ts
#    |      |     0.06s generating sentence-nodes with features nsent
#    |      |      |     0.03s 1394 sentence nodes have values assigned for nsent
#    |      |      |     0.03s  1423x Items contained in extra generated text
#    |      |      |     0.03s    66x Items with empty final text
#    |      |     0.09s 1394 sentences
#    |     4.19s Make a modified dataset ...
#   0.00s Feature overview: 67 for nodes; 3 for edges; 1 configs; 9 computed
#    |     4.60s Done
#   0.50s Enriched data is available in version 0.8.12
# You may need to adapt this TF app and its documentation:
# please run: python tfFromTei.py apptoken
# App updated with tokens and sentences
# True

# %% [markdown]
# ### Step 6: Use the new dataset

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.12</span>
# This is Text-Fabric 11.4.16
# 70 features found and 0 ignored
#    |     0.02s T otype                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.19s T oslots               from ~/github/annotation/mondriaan/tf/0.8.12
#   0.21s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.07s T after                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.08s T str                  from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T file                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T chunk                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T folder               from ~/github/annotation/mondriaan/tf/0.8.12
#    |      |     0.01s C __levels__           from otype, oslots, otext
#    |      |     0.25s C __order__            from otype, oslots, __levels__
#    |      |     0.01s C __rank__             from otype, __order__
#    |      |     0.32s C __levUp__            from otype, oslots, __rank__
#    |      |     0.17s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.01s C __characters__       from otext
#    |      |     0.08s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, file, chunk
#   1.21s All features loaded/computed - for details use TF.isLoaded()
#    |     0.00s T adaptation           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T artmondriaanref      from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T commodity            from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T corresp              from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T correspondent        from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T country              from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T dim                  from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T empty                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T exhibitionref        from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T extraspace           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T f                    from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T facs                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T form                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T id                   from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T institution          from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T is_meta              from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.01s T is_note              from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T key                  from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T lang                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T letterid             from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T level                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T location             from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T msid                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T n                    from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T name                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T nsent                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.01s T parent               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T period               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T periodlong           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T personref            from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T place                from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T quantity             from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T reason               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T ref                  from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_above           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_blockletter     from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_bold            from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_center          from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_indent          from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_italics         from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_overwritten     from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_right           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_right_underline from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_spaced          from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_super           from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_super_underline from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_super_underline2 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_underline       from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_underline2      from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T rend_upsidedown      from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T scheme               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T sender               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.03s T sibling              from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T source               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T target               from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T template             from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T type                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T unit                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T url                  from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T when                 from ~/github/annotation/mondriaan/tf/0.8.12
#    |     0.00s T who                  from ~/github/annotation/mondriaan/tf/0.8.12
#   0.10s All additional features loaded - for details use TF.isLoaded()
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.16</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.12</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>2</td>
#     <td>8550.50</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>biblio</th>
#     <td>1</td>
#     <td>3146.00</td>
#     <td>18</td>
# </tr>
#
# <tr>
#     <th>listBibl</th>
#     <td>2</td>
#     <td>1547.00</td>
#     <td>18</td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>16</td>
#     <td>1068.81</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>957.79</td>
#     <td>78</td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>16</td>
#     <td>664.75</td>
#     <td>62</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>16</td>
#     <td>664.75</td>
#     <td>62</td>
# </tr>
#
# <tr>
#     <th>artworks</th>
#     <td>1</td>
#     <td>546.00</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>listObject</th>
#     <td>1</td>
#     <td>501.00</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>31</td>
#     <td>326.03</td>
#     <td>59</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>14</td>
#     <td>314.00</td>
#     <td>26</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>51</td>
#     <td>125.80</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>46</td>
#     <td>95.57</td>
#     <td>26</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>222</td>
#     <td>76.97</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>16</td>
#     <td>119.12</td>
#     <td>11</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>69.00</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>96</td>
#     <td>67.26</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>62.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>artwork</th>
#     <td>10</td>
#     <td>47.70</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>105</td>
#     <td>42.93</td>
#     <td>26</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>16</td>
#     <td>42.06</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>109</td>
#     <td>28.71</td>
#     <td>18</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>16</td>
#     <td>22.44</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>16</td>
#     <td>18.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>15.86</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>30</td>
#     <td>12.83</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>4</td>
#     <td>12.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>1394</td>
#     <td>11.59</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>desc</th>
#     <td>10</td>
#     <td>11.10</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>159</td>
#     <td>10.33</td>
#     <td>10</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>8.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>classDecl</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>encodingDesc</th>
#     <td>1</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>7.75</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>168</td>
#     <td>5.75</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>28</td>
#     <td>5.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>56</td>
#     <td>5.12</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>6</td>
#     <td>4.83</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>26</td>
#     <td>4.73</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>14</td>
#     <td>4.14</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>4.14</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>1</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>6</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>3.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>3.39</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>67</td>
#     <td>3.24</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>catRef</th>
#     <td>43</td>
#     <td>3.16</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>30</td>
#     <td>2.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>15</td>
#     <td>2.47</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>2.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>49</td>
#     <td>2.41</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>2.33</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>190</td>
#     <td>2.27</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>14</td>
#     <td>2.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>65</td>
#     <td>2.06</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>abbr</th>
#     <td>2</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>taxonomy</th>
#     <td>4</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>1.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>11</td>
#     <td>1.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>11</td>
#     <td>1.18</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.12</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>16</td>
#     <td>1.12</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>16906</td>
#     <td>1.00</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>?editem</th>
#     <td>15</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>expan</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>73</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>5</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>measure</th>
#     <td>20</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>82</td>
#     <td>1.00</td>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 28 artwork-ms<br>
