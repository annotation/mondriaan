# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.advanced.helpers import dm

# %%
ORG = "annotation"
REPO = "mondriaan"

# %% [markdown]
# # Convert from TEI to TF
#
# We show how to convert a TEI data source into TF.
#
# This has two stages:
#
# 1. make an preliminary TF dataset with the character as slot type
# 1. feed the plain text to a tokenizer, and add tokens and sentences to the datset,
#    while removing its character and word nodes;
#    the new slot type is token.
#
# A dataset based on characters is precise, but rather inefficient.
# The second step makes the dataset much more efficient.

# %% [markdown]
# **More ways to do it!**
#
# * [convertExpress](convertExpress.ipynb) : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * *convertDetails*: run from Python with full control

# %% [markdown]
# ## Preliminary conversion
#
# Same as in [convertSteps](convertSteps.ipynb) but now with even more feedback.

# %% [markdown]
# ### Step 1: Check
#
# Check the input: validity of the TEI-XML.
#
# Make a report of the elements and attributes used.
#
# Use the declared schemas in the XML source to determine which elements have
# pure content and which ones mixed content.

# %%
Tei = TEI(verbose=-1, tei=0, tf="0.8.9pre")

# %%
Tei.task(check=True)
# Out:
# Start folder proeftuin:
#   14 19100131_SAAL_ARNO_0018.xml
# End   folder proeftuin
#
# Validation OK
# 14 processing instructions encountered.
# Namespaces OK
# True

# %% [markdown]
# ### Step 2: Convert
#
# Run the actual conversin and produce TF output.

# %%
Tei.task(convert=True)
# Out:
# Start folder proeftuin:
#   14 19100131_SAAL_ARNO_0018.xml
# End   folder proeftuin
# True

# %% [markdown]
# ### Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and precomputations are performed.
# Next time the loading will be much quicker.

# %%
Tei.task(load=True)
# Out:
# True

# %% [markdown]
# ### Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# ## View the preliminary result

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.9pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.16</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.9pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>62386.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>4456.14</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>2169.43</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>2169.43</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>702.64</td>
#     <td>16</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>100</td>
#     <td>623.73</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>30</td>
#     <td>1011.47</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>14</td>
#     <td>1570.86</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>51</td>
#     <td>544.61</td>
#     <td>45</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>46</td>
#     <td>478.09</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>424.07</td>
#     <td>10</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>90</td>
#     <td>313.77</td>
#     <td>45</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>250.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>95</td>
#     <td>231.35</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>204.50</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>117.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>76.93</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>68.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>30</td>
#     <td>50.67</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>4</td>
#     <td>41.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>35.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>168</td>
#     <td>35.34</td>
#     <td>10</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>27.75</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>24.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>20.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>61</td>
#     <td>18.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>6</td>
#     <td>18.17</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>6</td>
#     <td>15.83</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>15.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>28</td>
#     <td>15.04</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>56</td>
#     <td>21.68</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>190</td>
#     <td>13.74</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>13.02</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>12.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>expan</th>
#     <td>2</td>
#     <td>11.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>11.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>9.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>62</td>
#     <td>8.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>30</td>
#     <td>8.53</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>abbr</th>
#     <td>2</td>
#     <td>8.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>7.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>7.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>15</td>
#     <td>7.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>6.86</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>4.78</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>10846</td>
#     <td>4.57</td>
#     <td>79</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>14</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>49</td>
#     <td>2.92</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>11</td>
#     <td>2.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>11</td>
#     <td>2.18</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>?editem</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>63</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>5</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>78</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>62386</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/adaptation.tf">adaptation</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute adaptation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/a
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 28 artwork-ms<br>

# %% [markdown]
# We hoist the API handles of this dataset to the global scope.

# %%
Apre.hoist(globals())
# Out:
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ### Show a fragment

# %%
chunk = F.otype.s("chunk")[4]
Apre.plain(chunk)
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:5">proeftuin@19090216y_IONG_1303:5</a></span></span>  <span class="txtu">B</span><span class="txtu">e</span><span class="txtu">s</span><span class="txtu">t</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">Z</span><span class="txtu">u</span><span class="txtu">s</span><span class="txtu">,</span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">​</span><span class="txtu">k</span><span class="txtu">o</span><span class="txtu">m</span><span class="txtu"> </span><span class="txtu">j</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">m</span><span class="txtu">o</span><span class="txtu">r</span><span class="txtu">g</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu">a</span><span class="txtu">v</span><span class="txtu">o</span><span class="txtu">n</span><span class="txtu">d</span><span class="txtu"> </span><span class="txtu">(</span><span class="txtu">W</span><span class="txtu">o</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu">s</span><span class="txtu">d</span><span class="txtu">a</span><span class="txtu">g</span><span class="txtu">)</span><span class="txtu"> </span><span class="txtu">o</span><span class="txtu">m</span><span class="txtu"> </span><span class="txtu">k</span><span class="txtu">w</span><span class="txtu">a</span><span class="txtu">r</span><span class="txtu">t</span><span class="txtu"> </span><span class="txtu">v</span><span class="txtu">o</span><span class="txtu">o</span><span class="txtu">r</span><span class="txtu"> </span><span class="txtu">a</span><span class="txtu">c</span><span class="txtu">h</span><span class="txtu">t</span><span class="txtu"> </span><span class="txtu">i</span><span class="txtu">n</span><span class="txtu">g</span><span class="txtu">a</span><span class="txtu">n</span><span class="txtu">g</span><span class="txtu"> </span><span class="txtu">k</span><span class="txtu">l</span><span class="txtu">e</span><span class="txtu">i</span><span class="txtu">n</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">z</span><span class="txtu">a</span><span class="txtu">a</span><span class="txtu">l</span><span class="txtu"> </span><span class="txtu">C</span><span class="txtu">o</span><span class="txtu">n</span><span class="txtu">c</span><span class="txtu">e</span><span class="txtu">r</span><span class="txtu">t</span><span class="txtu">g</span><span class="txtu">e</span><span class="txtu">b</span><span class="txtu">o</span><span class="txtu">u</span><span class="txtu">w</span><span class="txtu">​</span><span class="txtu">,</span><span class="txtu"> </span><span class="txtu"> </span><span class="txtu">d</span><span class="txtu">a</span><span class="txtu">n</span><span class="txtu"> </span><span class="txtu">h</span><span class="txtu">e</span><span class="txtu">b</span><span class="txtu"> </span><span class="txtu">i</span><span class="txtu">k</span><span class="txtu"> </span><span class="txtu">e</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu"> </span><span class="txtu">p</span><span class="txtu">l</span><span class="txtu">a</span><span class="txtu">a</span><span class="txtu">t</span><span class="txtu">s</span><span class="txtu"> </span><span class="txtu">v</span><span class="txtu">o</span><span class="txtu">o</span><span class="txtu">r</span><span class="txtu"> </span><span class="txtu">v</span><span class="txtu">​</span><span class="txtu">.</span><span class="txtu"> </span><span class="txtu"> </span><span class="txtu">B</span><span class="txtu">u</span><span class="txtu">l</span><span class="txtu">h</span><span class="txtu">l</span><span class="txtu">i</span>< ...

# %% [markdown]
# ## Show the processing instructions

# %%
for nodeType in F.otype.all:
    if nodeType.startswith("?"):
        for n in F.otype.s(nodeType):
            Apre.pretty(n, multiFeatures=True)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739">proeftuin@19090407y_IONG_1739</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304">proeftuin@19090421y_IONG_1304</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090426y_IONG_1738/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090426y_IONG_1738">proeftuin@19090426y_IONG_1738</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293">proeftuin@19090513y_IONG_1293</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090624_IONG_1294/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090624_IONG_1294">proeftuin@19090624_IONG_1294</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090807y_IONG_1296/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090807y_IONG_1296">proeftuin@19090807y_IONG_1296</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090824y_KNAP_1747/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090824y_KNAP_1747">proeftuin@19090824y_KNAP_1747</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090905y_IONG_1295/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090905y_IONG_1295">proeftuin@19090905y_IONG_1295</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/190909XX_QUER_1654/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@190909XX_QUER_1654">proeftuin@190909XX_QUER_1654</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091024_SPOO_0016/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091024_SPOO_0016">proeftuin@19091024_SPOO_0016</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091024y_IONG_1297/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091024y_IONG_1297">proeftuin@19091024y_IONG_1297</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091025y_IONG_1298/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091025y_IONG_1298">proeftuin@19091025y_IONG_1298</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19100131_SAAL_ARNO_0018/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19100131_SAAL_ARNO_0018">proeftuin@19100131_SAAL_ARNO_0018</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="features"><span class="adaptation xft" ><span class="f">adaptation=</span>md</span><span class="template xft" ><span class="f">template=</span>letter</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>​</span><span class="empty xft" ><span class="f">empty=</span>1</span></div></div></div></div></div>

# %% [markdown]
# ## Check the extra features

# %%
features = tuple(feat for feat in Fall() if Fs(feat).meta.get("conversionCode", None) == "tt")

for feat in features:
    meta = Fs(feat).meta
    print(f"{feat:<15}: {meta['conversionCode']}: {meta['conversionMethod']}")
# Out:
# artmondriaanref: tt: derived
# correspondent  : tt: derived
# country        : tt: derived
# exhibitionref  : tt: derived
# institution    : tt: derived
# letterid       : tt: derived
# location       : tt: derived
# msid           : tt: derived
# period         : tt: derived
# periodlong     : tt: derived
# personref      : tt: derived
# sender         : tt: derived

# %%
for letter in F.otype.s("letter"):
    Apre.pretty(letter, extraFeatures=features)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303">proeftuin@19090216y_IONG_1303</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090216y_IONG_1303</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090216y_IONG_1303</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 123.397</span><span class="period xft" ><span class="f">period=</span>1909-02-16</span><span class="periodlong xft" ><span class="f">periodlong=</span>dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739">proeftuin@19090407y_IONG_1739</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090407y_IONG_1739</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090407y_IONG_1739</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 122.574</span><span class="period xft" ><span class="f">period=</span>1909-04-07</span><span class="periodlong xft" ><span class="f">periodlong=</span>woensdag 7 april 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304">proeftuin@19090421y_IONG_1304</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090421y_IONG_1304</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090421y_IONG_1304</span><span class="location xft" ><span class="f">location=</span>Amsterdam[?]</span><span class="msid xft" ><span class="f">msid=</span>KM 120.999</span><span class="period xft" ><span class="f">period=</span>1909-04</span><span class="periodlong xft" ><span class="f">periodlong=</span>tussen maandag 19 en vrijdag 23 april 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090426y_IONG_1738/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090426y_IONG_1738">proeftuin@19090426y_IONG_1738</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090426y_IONG_1738</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090426y_IONG_1738</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 118.535</span><span class="period xft" ><span class="f">period=</span>1909-04-26</span><span class="periodlong xft" ><span class="f">periodlong=</span>maandag 26 april 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293">proeftuin@19090513y_IONG_1293</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090513y_IONG_1293</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090513y_IONG_1293</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 121.570</span><span class="period xft" ><span class="f">period=</span>1909-05-13</span><span class="periodlong xft" ><span class="f">periodlong=</span>donderdag 13 mei 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090624_IONG_1294/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090624_IONG_1294">proeftuin@19090624_IONG_1294</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090624_IONG_1294</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090624_IONG_1294</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 114.029</span><span class="period xft" ><span class="f">period=</span>1909-06-24</span><span class="periodlong xft" ><span class="f">periodlong=</span>donderdag 24 juni 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090807y_IONG_1296/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090807y_IONG_1296">proeftuin@19090807y_IONG_1296</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090807y_IONG_1296</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090807y_IONG_1296</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 115.637</span><span class="period xft" ><span class="f">period=</span>1909-08</span><span class="periodlong xft" ><span class="f">periodlong=</span>eerste helft augustus 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090824y_KNAP_1747/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090824y_KNAP_1747">proeftuin@19090824y_KNAP_1747</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090824y_KNAP_1747</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Gerrit Willem Knap</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>-</span><span class="letterid xft" ><span class="f">letterid=</span>19090824y_KNAP_1747</span><span class="location xft" ><span class="f">location=</span>Zoutelande</span><span class="msid xft" ><span class="f">msid=</span>Privécollectie Chris Smeenk</span><span class="period xft" ><span class="f">period=</span>1909-08-24</span><span class="periodlong xft" ><span class="f">periodlong=</span>c. dinsdag 24 augustus 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090905y_IONG_1295/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090905y_IONG_1295">proeftuin@19090905y_IONG_1295</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090905y_IONG_1295</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19090905y_IONG_1295</span><span class="location xft" ><span class="f">location=</span>Domburg</span><span class="msid xft" ><span class="f">msid=</span>KM 117.523</span><span class="period xft" ><span class="f">period=</span>1909-09</span><span class="periodlong xft" ><span class="f">periodlong=</span>begin september 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/190909XX_QUER_1654/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@190909XX_QUER_1654">proeftuin@190909XX_QUER_1654</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@190909XX_QUER_1654</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Israël Querido</span><span class="country xft" ><span class="f">country=</span>-</span><span class="institution xft" ><span class="f">institution=</span>-</span><span class="letterid xft" ><span class="f">letterid=</span>190909XX_QUER_1654</span><span class="location xft" ><span class="f">location=</span>Domburg</span><span class="msid xft" ><span class="f">msid=</span>Publicatie; zie "pubhistory"</span><span class="period xft" ><span class="f">period=</span>1909-09</span><span class="periodlong xft" ><span class="f">periodlong=</span>september 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091024_SPOO_0016/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091024_SPOO_0016">proeftuin@19091024_SPOO_0016</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19091024_SPOO_0016</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Cornelis Spoor</span><span class="country xft" ><span class="f">country=</span>Onbekend</span><span class="institution xft" ><span class="f">institution=</span>Onbekend</span><span class="letterid xft" ><span class="f">letterid=</span>19091024_SPOO_0016</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>Onbekend</span><span class="period xft" ><span class="f">period=</span>1909-10-24</span><span class="periodlong xft" ><span class="f">periodlong=</span>zondag 24 oktober 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091024y_IONG_1297/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091024y_IONG_1297">proeftuin@19091024y_IONG_1297</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19091024y_IONG_1297</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19091024y_IONG_1297</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>KM 122.825</span><span class="period xft" ><span class="f">period=</span>1909-10-24</span><span class="periodlong xft" ><span class="f">periodlong=</span>tussen 18 en 31 oktober 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091025y_IONG_1298/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19091025y_IONG_1298">proeftuin@19091025y_IONG_1298</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19091025y_IONG_1298</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Aletta de Iongh</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>Kröller Müller Museum</span><span class="letterid xft" ><span class="f">letterid=</span>19091025y_IONG_1298</span><span class="location xft" ><span class="f">location=</span>Amsterdam[?]</span><span class="msid xft" ><span class="f">msid=</span>KM 113.571</span><span class="period xft" ><span class="f">period=</span>1909-10</span><span class="periodlong xft" ><span class="f">periodlong=</span>tussen dinsdag 19 oktober en c. woensdag 3 november 1909</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19100131_SAAL_ARNO_0018/&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19100131_SAAL_ARNO_0018">proeftuin@19100131_SAAL_ARNO_0018</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19100131_SAAL_ARNO_0018</span></span></span></div><div class="features"><span class="correspondent xft" ><span class="f">correspondent=</span>Arnold Saalborn</span><span class="country xft" ><span class="f">country=</span>Nederland</span><span class="institution xft" ><span class="f">institution=</span>RKD – Nederlands Instituut voor Kunstgeschiedenis</span><span class="letterid xft" ><span class="f">letterid=</span>19100131_SAAL_ARNO_0018</span><span class="location xft" ><span class="f">location=</span>Amsterdam</span><span class="msid xft" ><span class="f">msid=</span>Archief van de werkgroep Mondriaan correspondentieproject (0613) inv.nr. 71</span><span class="period xft" ><span class="f">period=</span>1910-01-31</span><span class="periodlong xft" ><span class="f">periodlong=</span>maandag 31 januari 1910</span><span class="sender xft" ><span class="f">sender=</span>Piet Mondriaan</span></div></div></div>

# %%
for feature in ("personref", "artmondriaanref", "artref", "exhibitionref"):
    fObj = Fs(feature)
    if fObj:
        items = list(fObj.items())
        nItems = len(items)
        dm(f"### {feature} with {nItems} items\n\n")
        for (node, pref) in items[0:5]:
            Apre.pretty(node, extraFeatures=f"ref key {feature}", baseTypes={"word"})
    else:
        dm(f"### {feature} with 0 items\n\n")
# Out:
# ### personref with 112 items
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="personref xft" ><span class="f">personref=</span>bio.xml#iongh_aletta_de</span><span class="ref xft" ><span class="f">ref=</span>bio.xml#iongh_aletta_de</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_meta">A</span></span><span class="txtu"><span class=" is_meta">l</span></span><span class="txtu"><span class=" is_meta">e</span></span><span class="txtu"><span class=" is_meta">t</span></span><span class="txtu"><span class=" is_meta">t</span></span><span class="txtu"><span class=" is_meta">a</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_meta">d</span></span><span class="txtu"><span class=" is_meta">e</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_meta">I</span></span><span class="txtu"><span class=" is_meta">o</span></span><span class="txtu"><span class=" is_meta">n</span></span><span class="txtu"><span class=" is_meta">g</span></span><span class="txtu"><span class=" is_meta">h</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:5">proeftuin@19090216y_IONG_1303:5</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="personref xft" ><span class="f">personref=</span>bio.xml#buhlig_richard</span><span class="ref xft" ><span class="f">ref=</span>bio.xml#buhlig_richard</span></div><div class="children hor wrap "><div class="contnr c1 trm  rno " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain  rno " ><span class="txtu">B</span><span class="txtu">u</span></span></span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">del </span></div><div class="children hor wrap "><div class="contnr c1 trm  lno rno " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain  lno rno " ><span class="txtu">l</span></span></span></div></div></div></div><div class="contnr c1 trm  lno " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain  lno " ><span class="txtu">h</span><span class="txtu">l</span><span class="txtu">i</span><span class="txtu">g</span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/6&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:6">proeftuin@19090216y_IONG_1303:6</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="personref xft" ><span class="f">personref=</span>bio.xml#buhlig_richard</span><span class="ref xft" ><span class="f">ref=</span>bio.xml#buhlig_richard</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">B</span><span class="txtu">u</span><span class="txtu">h</span><span class="txtu">l</span><span class="txtu">i</span><span class="txtu">g</span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:7">proeftuin@19090216y_IONG_1303:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="personref xft" ><span class="f">personref=</span>bio.xml#buhlig_richard</span><span class="ref xft" ><span class="f">ref=</span>bio.xml#buhlig_richard</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">R</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">c</span></span><span class="txtu"><span class=" is_note">h</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">r</span></span><span class="txtu"><span class=" is_note">d</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">B</span></span><span class="txtu"><span class=" is_note">u</span></span><span class="txtu"><span class=" is_note">h</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">g</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:7">proeftuin@19090216y_IONG_1303:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="personref xft" ><span class="f">personref=</span>bio.xml#iongh_aletta_de</span><span class="ref xft" ><span class="f">ref=</span>bio.xml#iongh_aletta_de</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">A</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">a</span></span></span></span></div></div></div></div></div>
# ### artmondriaanref with 18 items
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304:5">proeftuin@19090421y_IONG_1304:5</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="artmondriaanref xft" ><span class="f">artmondriaanref=</span></span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">d</span><span class="txtu">e</span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">s</span><span class="txtu">c</span><span class="txtu">h</span><span class="txtu">e</span><span class="txtu">t</span><span class="txtu">s</span><span class="txtu">e</span><span class="txtu">n</span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304:7">proeftuin@19090421y_IONG_1304:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>https://rkd.nl/images/277201</span><span class="artmondriaanref xft" ><span class="f">artmondriaanref=</span>https://rkd.nl/images/277201</span></div><div><div class="graphic_set"><div class="graphic_item"><span class="graphic_caption"><a target="_blank" href="https://rkd.nl/explore/images/https://rkd.nl/images/277201" title="visit this artwork on the RKD site">RKD https://rkd.nl/images/277201►</a></span></div></div></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">M</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">j</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">k</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">p</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304:7">proeftuin@19090421y_IONG_1304:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>htpps://rkd.nl/images/68554</span><span class="artmondriaanref xft" ><span class="f">artmondriaanref=</span>htpps://rkd.nl/images/68554</span></div><div><div class="graphic_set"><div class="graphic_item"><span class="graphic_caption"><a target="_blank" href="https://rkd.nl/explore/images/htpps://rkd.nl/images/68554" title="visit this artwork on the RKD site">RKD htpps://rkd.nl/images/68554►</a></span></div></div></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">F</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">m</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">e</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">u</span></span><span class="txtu"><span class=" is_note">d</span></span><span class="txtu"><span class=" is_note">e</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note">:</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">b</span></span><span class="txtu"><span class=" is_note">u</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">t</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">p</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">r</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">r</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">t</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090905y_IONG_1295/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090905y_IONG_1295:7">proeftuin@19090905y_IONG_1295:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>https://rkd.nl/images/62319</span><span class="artmondriaanref xft" ><span class="f">artmondriaanref=</span>https://rkd.nl/images/62319</span></div><div><div class="graphic_set"><div class="graphic_item"><span class="graphic_caption"><a target="_blank" href="https://rkd.nl/explore/images/https://rkd.nl/images/62319" title="visit this artwork on the RKD site">RKD https://rkd.nl/images/62319►</a></span></div></div></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">hi </span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class="r_italics is_note">Z</span></span><span class="txtu"><span class="r_italics is_note">e</span></span><span class="txtu"><span class="r_italics is_note">e</span></span><span class="txtu"><span class="r_italics is_note">l</span></span><span class="txtu"><span class="r_italics is_note">a</span></span><span class="txtu"><span class="r_italics is_note">n</span></span><span class="txtu"><span class="r_italics is_note">d</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class="r_italics is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class="r_italics is_note">f</span></span><span class="txtu"><span class="r_italics is_note">a</span></span><span class="txtu"><span class="r_italics is_note">r</span></span><span class="txtu"><span class="r_italics is_note">m</span></span><span class="txtu"><span class="r_italics is_note">e</span></span><span class="txtu"><span class="r_italics is_note">r</span></span></span></span></div></div></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090905y_IONG_1295/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090905y_IONG_1295:7">proeftuin@19090905y_IONG_1295:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>https://rkd.nl/images/68733</span><span class="artmondriaanref xft" ><span class="f">artmondriaanref=</span>https://rkd.nl/images/68733</span></div><div><div class="graphic_set"><div class="graphic_item"><span class="graphic_caption"><a target="_blank" href="https://rkd.nl/explore/images/https://rkd.nl/images/68733" title="visit this artwork on the RKD site">RKD https://rkd.nl/images/68733►</a></span></div></div></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">hi </span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class="r_italics is_note">Z</span></span><span class="txtu"><span class="r_italics is_note">e</span></span><span class="txtu"><span class="r_italics is_note">e</span></span><span class="txtu"><span class="r_italics is_note">l</span></span><span class="txtu"><span class="r_italics is_note">a</span></span><span class="txtu"><span class="r_italics is_note">n</span></span><span class="txtu"><span class="r_italics is_note">d</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class="r_italics is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class="r_italics is_note">g</span></span><span class="txtu"><span class="r_italics is_note">i</span></span><span class="txtu"><span class="r_italics is_note">r</span></span><span class="txtu"><span class="r_italics is_note">l</span></span></span></span></div></div></div></div></div></div></div>
#   6.85s Node feature "artref" not loaded
# ### artref with 0 items
# ### exhibitionref with 15 items
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739:7">proeftuin@19090407y_IONG_1739:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>expo.xml#sint_lucas_1909</span><span class="exhibitionref xft" ><span class="f">exhibitionref=</span>expo.xml#sint_lucas_1909</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">S</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">t</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">L</span></span><span class="txtu"><span class=" is_note">u</span></span><span class="txtu"><span class=" is_note">c</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">-</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">g</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293:5">proeftuin@19090513y_IONG_1293:5</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>expo.xml#sint_lucas_1909</span><span class="exhibitionref xft" ><span class="f">exhibitionref=</span>expo.xml#sint_lucas_1909</span></div><div class="children hor wrap "><div class="contnr c1 trm  rno " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain  rno " ><span class="txtu">S</span></span></span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">hi </span></div><div class="children hor wrap "><div class="contnr c1 trm  lno " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain  lno " ><span class="txtu"><span class="r_ ">t</span></span></span></span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">L</span><span class="txtu">u</span><span class="txtu">c</span><span class="txtu">a</span><span class="txtu">s</span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/6&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293:6">proeftuin@19090513y_IONG_1293:6</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>expo.xml#sint_lucas_1909</span><span class="exhibitionref xft" ><span class="f">exhibitionref=</span>expo.xml#sint_lucas_1909</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">S</span><span class="txtu">t</span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">L</span><span class="txtu">u</span><span class="txtu">c</span><span class="txtu">a</span><span class="txtu">s</span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/7&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293:7">proeftuin@19090513y_IONG_1293:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="key " ><span class="f">key=</span>expo.xml#sint_lucas_1909</span><span class="exhibitionref xft" ><span class="f">exhibitionref=</span>expo.xml#sint_lucas_1909</span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">J</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">a</span></span><span class="txtu"><span class=" is_note">r</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">j</span></span><span class="txtu"><span class=" is_note">k</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">c</span></span><span class="txtu"><span class=" is_note">h</span></span><span class="txtu"><span class=" is_note">e</span></span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_note"> </span></span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu"><span class=" is_note">T</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">o</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">s</span></span><span class="txtu"><span class=" is_note">t</span></span><span class="txtu"><span class=" is_note">e</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">l</span></span><span class="txtu"><span class=" is_note">i</span></span><span class="txtu"><span class=" is_note">n</span></span><span class="txtu"><span class=" is_note">g</span></span></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/190909XX_QUER_1654/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@190909XX_QUER_1654:5">proeftuin@190909XX_QUER_1654:5</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="exhibitionref xft" ><span class="f">exhibitionref=</span></span></div><div class="children hor wrap "><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">d</span><span class="txtu">e</span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">j</span><span class="txtu">a</span><span class="txtu">a</span><span class="txtu">r</span><span class="txtu">l</span><span class="txtu">i</span><span class="txtu">j</span><span class="txtu">k</span><span class="txtu">s</span><span class="txtu">c</span><span class="txtu">h</span><span class="txtu">e</span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">t</span><span class="txtu">e</span></span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"> </span></div></div><div class="contnr c1 trm   " ><div class="lbl c1 trm " ><span class="nd">word </span> <span class="txtu"><span class="plain   " ><span class="txtu">A</span><span class="txtu">r</span><span class="txtu">n</span><span class="txtu">h</span><span class="txtu">e</span><span class="txtu">m</span></span></span></div></div></div></div></div>

# %% [markdown]
# ## Memory resources
#
# Check the memory usage per feature.
#
# Keep an eye on the footprint of the `sibling` feature, because it might become too large
# in a bigger corpus.

# %%
Apre.footprint()
# Out:
# # 70 features
#
# feature | members | size in bytes
# --- | --- | ---
# __levUp__ | 75,109 | 4,962,896
# ch | 62,386 | 4,373,868
# oslots | 3 | 3,370,288
# __boundary__ | 2 | 2,822,488
# __order__ | 75,109 | 2,703,964
# is_note | 25,415 | 2,022,470
# __levDown__ | 12,723 | 1,528,432
# is_meta | 11,356 | 907,930
# str | 10,846 | 740,014
# after | 10,846 | 605,101
# sibling | 949 | 366,804
# __rank__ | 75,109 | 319,304
# parent | 1,641 | 288,604
# otype | 4 | 105,793
# extraspace | 804 | 59,514
# empty | 464 | 31,504
# type | 386 | 31,214
# id | 320 | 22,884
# rend_italics | 308 | 17,956
# n | 277 | 17,766
# rend_underline | 212 | 15,268
# __levels__ | 69 | 14,897
# __characters__ | 1 | 14,559
# target | 139 | 14,164
# __sections__ | 2 | 10,785
# personref | 112 | 9,575
# ref | 112 | 9,575
# who | 127 | 8,550
# chunk | 100 | 7,712
# url | 63 | 7,279
# rend_upsidedown | 90 | 7,236
# rend | 72 | 5,152
# lang | 74 | 4,438
# facs | 48 | 4,036
# f | 46 | 3,654
# key | 34 | 3,575
# rend_spaced | 38 | 2,260
# rend_blockletter | 34 | 2,148
# periodlong | 14 | 2,113
# letter | 14 | 1,977
# letterid | 14 | 1,977
# msid | 14 | 1,972
# artmondriaanref | 18 | 1,950
# period | 14 | 1,720
# when | 14 | 1,720
# exhibitionref | 15 | 1,397
# institution | 14 | 1,397
# correspondent | 14 | 1,369
# location | 14 | 1,258
# form | 14 | 1,206
# country | 14 | 1,189
# sender | 14 | 1,087
# template | 14 | 1,079
# adaptation | 14 | 1,075
# rend_super | 12 | 996
# unit | 9 | 712
# quantity | 9 | 704
# dim | 9 | 661
# rend_above | 8 | 604
# rend_center | 6 | 548
# rend_right | 6 | 548
# rend_right_underline | 6 | 548
# place | 3 | 471
# rend_underline2 | 5 | 392
# rend_norend | 4 | 364
# reason | 2 | 339
# folder | 1 | 310
# rend_overwritten | 2 | 308
# rend_super_underline2 | 2 | 308
# rend_super_underline | 1 | 280
# TOTAL | 365,744 | 25,476,236

# %% [markdown]
# ## Add tokens and sentences
#
# We add tokens and sentences to the TF dataset.
#
# We do this by the following steps
#
# 1. Generate a plain text plus mapping between character positions and nodes
# 2. Use Spacy to tokenize the text and to determine sentence boundaries
# 3. translate the Spacy results back to extra nodes and features for the TF set
# 4. replace the character slots in the TF set by tokens

# %% [markdown]
# ### Step by step from Python
#
# We carry out the steps from within Python.
#
# In that way we get access to all intermediate results, and we can play and explore between the steps.
#
# We load the data we have so far, and pass it on to an `NLPipeline` object, defined by Text-Fabric.

# %% [markdown]
# ### Back to the previous state
#
# When we have added the data to the dataset, we will tweak the TF app.
#
# But if we want to redo the pipeline, we have to restore the app to the situation before
# the tokens and sentences were added.
#
# That's the reason we have the next cell.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone", hoist=globals())
NLP = NLPipeline(lang="en", verbose=0, write=True)
NLP.loadApp(Apre)
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.9pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.16</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.9pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>62386.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>4456.14</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>2169.43</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>2169.43</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>702.64</td>
#     <td>16</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>100</td>
#     <td>623.73</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>30</td>
#     <td>1011.47</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>14</td>
#     <td>1570.86</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>51</td>
#     <td>544.61</td>
#     <td>45</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>46</td>
#     <td>478.09</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>424.07</td>
#     <td>10</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>90</td>
#     <td>313.77</td>
#     <td>45</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>250.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>95</td>
#     <td>231.35</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>204.50</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>117.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>76.93</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>68.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>30</td>
#     <td>50.67</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>4</td>
#     <td>41.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>35.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>168</td>
#     <td>35.34</td>
#     <td>10</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>27.75</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>24.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>20.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>61</td>
#     <td>18.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>6</td>
#     <td>18.17</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>6</td>
#     <td>15.83</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>15.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>28</td>
#     <td>15.04</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>56</td>
#     <td>21.68</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>190</td>
#     <td>13.74</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>13.02</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>12.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>expan</th>
#     <td>2</td>
#     <td>11.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>11.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>9.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>62</td>
#     <td>8.55</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>30</td>
#     <td>8.53</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>abbr</th>
#     <td>2</td>
#     <td>8.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>7.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>7.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>15</td>
#     <td>7.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>6.86</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>4.78</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>10846</td>
#     <td>4.57</td>
#     <td>79</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>14</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>49</td>
#     <td>2.92</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>11</td>
#     <td>2.73</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>11</td>
#     <td>2.18</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>?editem</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>63</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>5</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>78</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>62386</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/adaptation.tf">adaptation</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute adaptation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9pre/a
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 28 artwork-ms<br>
# Input data has version 0.8.9pre
# Compute element boundaries
#   1210 start postions
#   1437 end postions

# %% [markdown]
# ### Before the steps
#
# We can set the verbosity as we like.

# %% [markdown]
# Generate plain text (add `verbose=-1` or `0` or `1` and/or `write=True` if you like).
#
# * `verbose=-1` is the same as `-verbose`
# * `verbose=0` is the same as `+verbose`
# * `verbose=1` is the same as `++verbose`

# %% [markdown]
# ### Step 1: Generate a plain text of the whole corpus
#
# The function delivers the text in a variable, and it has recorded which character positions correspond
# to which slots in the TF dataset.
#
# We receive both items of data.

# %%
(text, positions) = NLP.task(plaintext=True)
# Out:
# Input data has version 0.8.9pre
# Compute element boundaries
#   1210 start postions
#   1437 end postions
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 232 empty slots
#    |   recorded flow main       with 122399 items
#    |   recorded flow del        with    159 items
#    |   recorded flow note       with  66421 items
#    |   recorded flow orig       with    104 items
#   0.18s Done. Generated text and positions written to ~/github/annotation/mondriaan/_temp/txt/plain.txt

# %% [markdown]
# ### Step 2: Run Spacy to get tokens and sentences
#
# Now we feed the text from step 1 into the NLP pipeline, which is Spacy.
#
# We get a list of tokens and a list of sentences back.

# %%
(tokens, sentences) = NLP.task(lingo=True, text=text)
# Out:
# Input data has version 0.8.9pre
# Compute element boundaries
#   1210 start postions
#   1437 end postions
#   0.00s Using NLP pipeline Spacy (en) ...
#   2.95s Atomic tokens written to ~/github/annotation/mondriaan/_temp/txt/tokens.tsv
#   2.95s Sentences written to ~/github/annotation/mondriaan/_temp/txt/sentences.tsv
#   2.95s NLP done

# %% [markdown]
# Let's examine a few tokens and sentences:

# %%
for token in tokens[1022:1032]:
    print(token)
# Out:
# (3995, 4000, 'groot', ' ')
# (4001, 4005, 'deel', ' ')
# (4006, 4009, 'van', ' ')
# (4010, 4012, 'de', ' ')
# (4013, 4017, 'week', ' ')
# (4018, 4025, 'geweest', '')
# (4025, 4026, '.', ' ')
# (4027, 4029, 'Ik', ' ')
# (4030, 4033, 'woû', ' ')
# (4034, 4036, 'je', ' ')

# %%
for token in tokens[1211:1221]:
    print(token)
# Out:
# (4707, 4709, 'to', ' ')
# (4710, 4714, 'come', ' ')
# (4715, 4718, 'and', ' ')
# (4719, 4722, 'see', ' ')
# (4723, 4726, 'you', ' ')
# (4727, 4734, 'between', ' ')
# (4735, 4736, '4', ' ')
# (4737, 4740, 'and', ' ')
# (4741, 4742, '5', '')
# (4742, 4743, ',', ' ')

# %% [markdown]
# Each token entry specifies the start and end position in the plain text file,
# the string value of the token, and the whitespace after the token, if any.

# %%
for sentence in sentences[136:155]:
    print(sentence)
# Out:
# (3978, 4026, 'Ik ben er al een groot deel van de week geweest.')
# (4027, 4231, 'Ik woû je wel graag tusschen 4 - 5 even komen opzoeken, anders zie ik je weer in een week denkelijk niet, want ik ga met de Paaschdagen naar Arnhem.￮ Ik kom dus morgen even zien of je thuis ben.  xxx. ')
# (4231, 4239, 'Aa bb. ')
# (4239, 4248, 'End p. ')
# (4248, 4252, 'Dag!')
# (4253, 4290, 'Veel beste groeten je Piet.  xxx. ')
# (4290, 4298, 'Aa bb. ')
# (4298, 4319, 'End div.   xxx. ')
# (4319, 4327, 'Aa bb. ')
# (4327, 4342, 'End chunk.  ')
# (4342, 4350, 'Aa bb. ')
# (4350, 4628, 'Begin chunk. Dear Zus,I’m sorry I’m sending you such a crumpled envelope,￮ but I didn’t have any more in the house, and I had to tell you that unfortunately I have to be in the museum tomorrow afternoon when the paintings are hung because I’m on the St Lucas jury.￮  xxx. ')
# (4628, 4636, 'Aa bb. ')
# (4636, 4645, 'End p. ')
# (4645, 4697, 'I’ve already been there for a good part of the week.')
# (4698, 4900, 'I’d like to come and see you between 4 and 5, otherwise I don’t think I’ll see you again in a week, because I ‘m going to Arnhem for Easter.￮ So I’ll call round tomorrow to see if you’re home.  xxx. ')
# (4900, 4908, 'Aa bb. ')
# (4908, 4917, 'End p. ')
# (4917, 4921, 'Bye!')

# %% [markdown]
# Sentence entries have the same fields, except for the last whitespace field.
#
# Actually, the program will not use the texts of tokens and sentences for display, only for determining
# where the boundaries are.
#
# With those boundaries in hand, the texts of tokens and sentences are read off from the original corpus.

# %% [markdown]
# ### Step 3: Ingest the results in the data set
#
# A lot of critical things happen when we ingest the token and sentence streams into our dataset.
#
# We calculate slot positions, retrieve text, split some tokens, and last but not least,
# we replace the character-by-character basis of the preliminary dataset by a token-by-token basis.

# %%
Apre.pretty(L.u(2957, otype="word")[0], multiFeatures=True)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/5&amp;version=0.8.9pre" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739:5">proeftuin@19090407y_IONG_1739:5</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">word </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="str xft" ><span class="f">str=</span>St</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">S</span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>S</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class="r_ ">t</span></span></div><div class="features"><span class="ch xft" ><span class="f">ch=</span>t</span><span class="rend_super_underline xft" ><span class="f">rend_super_underline=</span>1</span></div></div></div></div></div>

# %%
newVersion = NLP.task(
    ingest=True,
    positions=positions,
    tokens=tokens,
    sentences=sentences,
)
# Out:
# Input data has version 0.8.9pre
# Compute element boundaries
#   1210 start postions
#   1437 end postions
#   0.00s Ingesting tokens, and sentences into the dataset ...
#    |     8.69s Mapping NLP data to nodes and features ...
#    |      |     0.00s generating t-nodes with features str, after, empty
#    |      |      |     0.00s 13405 t nodes have values assigned for str, after
#    |      |      |     0.00s 232 empty slots have surrounding split tokens
#    |      |      |     0.00s 68 space slots have split into chars
#    |      |      |     0.00s 1600 slots have split around an element boundary
#    |      |      |     0.00s  6497x Items contained in extra generated text
#    |      |     0.06s 13017 tokens
#    |      |     0.06s 13405 ts
#    |      |     0.06s generating sentence-nodes with features nsent
#    |      |      |     0.02s 1050 sentence nodes have values assigned for nsent
#    |      |      |     0.02s   977x Items contained in extra generated text
#    |      |      |     0.02s    61x Items with empty final text
#    |      |     0.08s 1050 sentences
#    |     8.77s Make a modified dataset ...
#   0.00s Feature overview: 59 for nodes; 3 for edges; 1 configs; 9 computed
#    |     9.07s Done
#   0.38s Enriched data is available in version 0.8.9
# You may need to adapt this TF app and its documentation:
# please run: python tfFromTei.py apptoken

# %% [markdown]
# ### Step 4: Adjust the app to the modified dataset
#
# Various things in the `config.yaml` and `app.py` of the TF app should be updated, as well
# as the documentation file that gives the ins and outs of the resulting features.

# %%
Tei.task(apptoken=True)
# Out:
# App updated with tokens and sentences
# True

# %% [markdown]
# # Use the new dataset
#
# We can now use the resulting dataset in the usual way.
# Because we have adapted the TF app, the version without the `pre` will now be loaded.

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone", silent="verbose")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.9</span>
# This is Text-Fabric 11.4.16
# 62 features found and 0 ignored
#    |     0.02s T otype                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.19s T oslots               from ~/github/annotation/mondriaan/tf/0.8.9
#   0.21s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T chunk                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.05s T after                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T letter               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.06s T str                  from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T folder               from ~/github/annotation/mondriaan/tf/0.8.9
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.13s C __order__            from otype, oslots, __levels__
#    |      |     0.01s C __rank__             from otype, __order__
#    |      |     0.26s C __levUp__            from otype, oslots, __rank__
#    |      |     0.13s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.01s C __characters__       from otext
#    |      |     0.07s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, letter, chunk
#   0.94s All features loaded/computed - for details use TF.isLoaded()
#    |     0.00s T adaptation           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T artmondriaanref      from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T correspondent        from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T country              from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T dim                  from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T empty                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T exhibitionref        from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T extraspace           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T f                    from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T facs                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T form                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T id                   from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T institution          from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T is_meta              from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.01s T is_note              from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T key                  from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T lang                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T letterid             from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T location             from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T msid                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T n                    from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T nsent                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.01s T parent               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T period               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T periodlong           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T personref            from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T place                from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T quantity             from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T reason               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T ref                  from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_above           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_blockletter     from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_center          from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_italics         from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_overwritten     from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_right           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_right_underline from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_spaced          from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_super           from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_super_underline from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_super_underline2 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_underline       from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_underline2      from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T rend_upsidedown      from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T sender               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.01s T sibling              from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T target               from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T template             from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T type                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T unit                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T url                  from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T when                 from ~/github/annotation/mondriaan/tf/0.8.9
#    |     0.00s T who                  from ~/github/annotation/mondriaan/tf/0.8.9
#   0.07s All additional features loaded - for details use TF.isLoaded()
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.16</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.9</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>13405.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>957.50</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>499.50</td>
#     <td>52</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>499.50</td>
#     <td>52</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>100</td>
#     <td>133.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>30</td>
#     <td>232.17</td>
#     <td>52</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>14</td>
#     <td>314.00</td>
#     <td>33</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>132.57</td>
#     <td>14</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>51</td>
#     <td>125.73</td>
#     <td>48</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>46</td>
#     <td>95.57</td>
#     <td>33</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>90</td>
#     <td>71.12</td>
#     <td>48</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>69.00</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>62.50</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>95</td>
#     <td>46.13</td>
#     <td>33</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>45.07</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>24.07</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>15.86</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>15.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>30</td>
#     <td>12.87</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>1050</td>
#     <td>12.02</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>4</td>
#     <td>9.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>8.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>7.75</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>5.81</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>168</td>
#     <td>5.75</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>28</td>
#     <td>5.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>56</td>
#     <td>5.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>4.14</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>6</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>6</td>
#     <td>3.83</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>3.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>3.39</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>61</td>
#     <td>3.07</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>3.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>30</td>
#     <td>2.60</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>15</td>
#     <td>2.47</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>2.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>49</td>
#     <td>2.41</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>2.33</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>190</td>
#     <td>2.27</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>14</td>
#     <td>2.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>62</td>
#     <td>2.05</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>abbr</th>
#     <td>2</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>1.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>11</td>
#     <td>1.27</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>11</td>
#     <td>1.18</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.12</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>13017</td>
#     <td>1.00</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>?editem</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>expan</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>63</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>5</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>78</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>13405</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.9/adaptation.tf">adaptation</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>this is TEI attribute adaptation</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Piet Mondriaan</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Leo Jansen, Peter Boot, Beatrice Nava, Mariken Teeuwen</div>
# </div>
#
# <div cla
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 28 artwork-ms<br>

# %% [markdown]
# We hoist the API handles of this dataset to the global scope.

# %%
A.hoist(globals())
# Out:
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ## Memory resources (revisited)
#
# We now have a leaner dataset, because the granularity has become coarser: from character
# to token.

# %%
A.footprint()
# Out:
# # 69 features
#
# feature | members | size in bytes
# --- | --- | ---
# __levUp__ | 29,349 | 5,495,104
# str | 26,422 | 2,196,373
# after | 26,042 | 2,040,075
# __boundary__ | 2 | 1,982,352
# __levDown__ | 15,944 | 1,909,040
# oslots | 3 | 1,893,612
# __order__ | 29,349 | 1,056,604
# sibling | 949 | 366,804
# parent | 1,641 | 288,604
# is_note | 4,382 | 270,290
# otype | 4 | 131,616
# is_meta | 1,856 | 125,826
# __rank__ | 29,349 | 121,180
# nsent | 1,050 | 95,752
# extraspace | 783 | 58,926
# type | 386 | 31,214
# id | 320 | 22,884
# n | 277 | 17,766
# empty | 232 | 15,800
# __levels__ | 70 | 15,056
# __characters__ | 1 | 14,655
# target | 139 | 14,164
# __sections__ | 2 | 10,757
# personref | 112 | 9,575
# ref | 112 | 9,575
# who | 127 | 8,550
# chunk | 100 | 7,712
# url | 63 | 7,279
# rend | 72 | 5,152
# lang | 74 | 4,438
# facs | 48 | 4,036
# rend_underline | 59 | 3,944
# f | 46 | 3,654
# rend_italics | 47 | 3,608
# key | 34 | 3,575
# periodlong | 14 | 2,113
# msid | 14 | 2,001
# letter | 14 | 1,977
# letterid | 14 | 1,977
# artmondriaanref | 18 | 1,950
# period | 14 | 1,720
# when | 14 | 1,720
# institution | 14 | 1,473
# exhibitionref | 15 | 1,397
# correspondent | 14 | 1,385
# location | 14 | 1,258
# form | 14 | 1,206
# country | 14 | 1,189
# rend_upsidedown | 17 | 1,136
# sender | 14 | 1,087
# template | 14 | 1,079
# adaptation | 14 | 1,075
# unit | 9 | 712
# quantity | 9 | 704
# dim | 9 | 661
# rend_blockletter | 6 | 548
# place | 3 | 471
# rend_super | 5 | 392
# rend_spaced | 4 | 364
# reason | 2 | 339
# folder | 1 | 310
# rend_above | 2 | 308
# rend_center | 2 | 308
# rend_overwritten | 2 | 308
# rend_right | 2 | 308
# rend_right_underline | 2 | 308
# rend_super_underline2 | 2 | 308
# rend_super_underline | 1 | 280
# rend_underline2 | 1 | 280
# TOTAL | 169,754 | 18,278,204

# %% [markdown]
# # Exploration
#
# We walk around a bit more in the corpus.

# %% [markdown]
# ## All titles:

# %%
for t in F.otype.s("titleStmt"):
    print(t, T.text(t))
# Out:
# 15251 Brief aan Aletta de Iongh. Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15252 Brief aan Aletta de Iongh. Amsterdam, woensdag 7 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15253 Brief aan Aletta de Iongh. Amsterdam, tussen maandag 19 en vrijdag 23 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15254 Brief aan Aletta de Iongh. Amsterdam, maandag 26 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15255 Brief aan Aletta de Iongh. Amsterdam, donderdag 13 mei 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15256 Brief aan Aletta de Iongh. Amsterdam, donderdag 24 juni 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15257 Brief aan Aletta de Iongh. Amsterdam, eerste helft augustus 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15258  Briefkaart aan Gerrit Willem Knap. Zoutelande, c. dinsdag 24 augustus 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15259 Brief aan Aletta de Iongh. Domburg, begin september 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15260 Brief aan Israël Querido. Domburg, september 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15261 Briefkaart aan Kees Spoor. Amsterdam, zondag 24 oktober 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15262 Brief aan Aletta de Iongh. Amsterdam, tussen 18 en 31 oktober 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15263 Brief aan Aletta de Iongh. Amsterdam, tussen dinsdag 19 oktober en c. woensdag 3 november 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15264 Brief aan ​. Amsterdam, maandag 31 januari 1910.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject

# %% [markdown]
# # Tokens
#
# Show all the tokens that are split into atomic tokens

# %%
query = """
token
  =: t
  <: t
"""

results = A.search(query)
# Out:
#   0.02s 10 results

# %%
A.table(results, condenseType="token")
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">token</th><th class="tf">t</th><th class="tf">t</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739:5">proeftuin@19090407y_IONG_1739:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">S </span></span><span class="plain   hl" ><span class="txtu"><span class="r_ ">t </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">S </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_ ">t </span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090426y_IONG_1738/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090426y_IONG_1738:5">proeftuin@19090426y_IONG_1738:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">1 </span></span><span class="plain   hl" ><span class="txtu"><span class="r_ ">e </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">1 </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_ ">e </span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090513y_IONG_1293/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090513y_IONG_1293:5">proeftuin@19090513y_IONG_1293:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">S </span></span><span class="plain   hl" ><span class="txtu"><span class="r_ ">t </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">S </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_ ">t </span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">4</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090624_IONG_1294/6&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090624_IONG_1294:6">proeftuin@19090624_IONG_1294:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">k </span></span><span class="plain   hl" ><span class="txtu">a </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">k </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">a </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">5</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090824y_KNAP_1747/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090824y_KNAP_1747:5">proeftuin@19090824y_KNAP_1747:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">42</span></span><span class="plain   hl" ><span class="txtu"><span class="r_super ">II</span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">42</span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_super ">II</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">6</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090824y_KNAP_1747/6&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090824y_KNAP_1747:6">proeftuin@19090824y_KNAP_1747:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">Vr. </span></span><span class="plain   hl" ><span class="txtu"><span class="r_super ">n </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">Vr. </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_super ">n </span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">7</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090905y_IONG_1295/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090905y_IONG_1295:5">proeftuin@19090905y_IONG_1295:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">4</span></span><span class="plain   hl" ><span class="txtu"><span class="r_super ">.a</span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">4</span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_super ">.a</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">8</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19091024y_IONG_1297/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19091024y_IONG_1297:5">proeftuin@19091024y_IONG_1297:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">Nov.</span></span><span class="plain   hl" ><span class="txtu"><span class="r_super ">ber </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">Nov.</span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu"><span class="r_super ">ber </span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">9</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19100131_SAAL_ARNO_0018/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19100131_SAAL_ARNO_0018:5">proeftuin@19100131_SAAL_ARNO_0018:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">on</span></span><span class="plain   hl" ><span class="txtu">juist </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">on</span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">juist </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">10</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19100131_SAAL_ARNO_0018/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19100131_SAAL_ARNO_0018:5">proeftuin@19100131_SAAL_ARNO_0018:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">e</span></span><span class="plain   hl" ><span class="txtu">en </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl" ><span class="txtu">e</span></span></span></td><td class="tf ltr"><span class=" ub

# %% [markdown]
# ## Sentences

# %%
for s in F.otype.s("sentence")[2:4]:
    print(T.text(s))
# Out:
# Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# Wietse Coppes

# %%
for s in F.otype.s("sentence")[2:4]:
    A.pretty(s, withNodes=True)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15285 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16339 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8 </span> <span class="txtu"><span class=" is_meta">Amsterdam</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16340 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">9 </span> <span class="txtu"><span class=" is_meta">, </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16341 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10 </span> <span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16342 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11 </span> <span class="txtu"><span class=" is_meta">16 </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16343 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12 </span> <span class="txtu"><span class=" is_meta">februari</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16344 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">13 </span> <span class="txtu"><span class=" is_meta">, </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16345 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">14 </span> <span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16346 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">15 </span> <span class="txtu"><span class=" is_meta">2 </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16347 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">16 </span> <span class="txtu"><span class=" is_meta">maart </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16348 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">17 </span> <span class="txtu"><span class=" is_meta">of </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16349 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">18 </span> <span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16350 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">19 </span> <span class="txtu"><span class=" is_meta">9 </span></span></div></div></div></div><div class="contnr c1    " ><div  ...
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15286 </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">editor:13941 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16355 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">24 </span> <span class="txtu"><span class=" is_meta">Wietse </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:16356 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">25 </span> <span class="txtu"><span class=" is_meta">Coppes</span></span></div></div></div></div></div></div></div></div></div>

# %%
for (i, s) in enumerate(F.otype.s("sentence")[0:100]):
    print(f"SENTENCE {i + 1}: {T.text(s)}")
# Out:
# SENTENCE 1: ​
# SENTENCE 2: Brief aan Aletta de Iongh.
# SENTENCE 3: Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# SENTENCE 4: Wietse Coppes
# SENTENCE 5: Leo Jansen
# SENTENCE 6: Mondriaan Editieproject
# SENTENCE 7: Nederland
# SENTENCE 8: Otterlo
# SENTENCE 9: Kröller Müller Museum
# SENTENCE 10: KM 123.397
# SENTENCE 11: 19090216y_IONG_1303
# SENTENCE 12: ​
# SENTENCE 13: ​
# SENTENCE 14: ​
# SENTENCE 15: Piet Mondriaan
# dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909
# Amsterdam
# Aletta de Iongh
# SENTENCE 16: transcriptie: voltooid 20.7.15
# collatie bron: 6.6.16
# tweede collatie aan het origineel: voltooid 26.11.19
# invoer tweede collatie: voltooid 5.8.16
# bespreking eindversie: gb
# markeren annotaties: in bewerking / voltooid
# gereed 17.4.2019
# titel gecontroleerd 21.09.2020
# personen getagd 12.10.2020
# vertaling ingevoerd 16.2.2021
# codering personen aangepast 16.2.2022
# controle/aanpassing afkortingen en emendaties 21.4.2023
# SENTENCE 17: ​​
# ​
# ​
# ​
# SENTENCE 18: Beste Zus,
# ​kom je morgenavond (Woensdag) om kwart voor acht ingang kleine zaal Concertgebouw,  dan heb ik een plaats voor v .  Buhlig voor je.​En dan kunnen we een andere dan Donderdagmiddag afspreken want dan kan ik niet goed.
# SENTENCE 19: ​
# SENTENCE 20: ​
# SENTENCE 21: l
# SENTENCE 22: Met vele beste groeten je Piet.
# SENTENCE 23: Dear Zus,​
# ​If you come to the entrance to the small auditorium in the Concertgebouw at a quarter to eight tomorrow (Wednesday) evening, I have a ticket for van Buhlig for you.​And then we can arrange a time other than Thursday afternoon because I can’t manage that.
# SENTENCE 24: With my very best wishes, your Piet.
# SENTENCE 25: Manuscript.
# SENTENCE 26: De brief is geschreven op een dinsdag voorafgaand aan een van de drie woensdagen waarop Richard Buhlig
# SENTENCE 27: in 1909 in de kleine zaal van het Concertgebouw een concert zou geven: 17 februari, 3 maart en 10 maart.
# SENTENCE 28: Zie tevens n. "plaatsBuhlig".
# SENTENCE 29: ​
# SENTENCE 30: Aletta
# SENTENCE 31: werd binnen haar familie aangesproken met de koosnaam 'Zus' (Heteren 2018, p. 25) Mondriaans gebruik van deze naam geeft aan dat hij op intieme voet stond met De Iongh.
# SENTENCE 32: De Amerikaanse pianist Richard Moritz Buhlig (1880-1952) gaf begin 1909 drie concerten in de kleine zaal van het Concertgebouw, op woensdag 17 februari, woensdag 3 maart en woensdag 10 maart.
# SENTENCE 33: Het is niet bekend voor welke van deze concerten Mondriaan kaarten had.
# SENTENCE 34: ​
# SENTENCE 35: Brief aan Aletta de Iongh.
# SENTENCE 36: Amsterdam, woensdag 7 april 1909.
# SENTENCE 37: Wietse Coppes
# SENTENCE 38: Leo Jansen
# SENTENCE 39: Mondriaan Editieproject
# SENTENCE 40: Nederland
# SENTENCE 41: Otterlo
# SENTENCE 42: Kröller Müller Museum
# SENTENCE 43: KM 122.574
# SENTENCE 44: 19090407y_IONG_1739
# SENTENCE 45: ​
# SENTENCE 46: ​
# SENTENCE 47: ​
# SENTENCE 48: Piet Mondriaan
# SENTENCE 49: woensdag 7 april 1909
# SENTENCE 50: Amsterdam
# SENTENCE 51: Aletta de Iongh
# SENTENCE 52: transcriptie: voltooid 18.8.16
# SENTENCE 53: collatie bron: voltooid 18.8.16
# SENTENCE 54: tweede collatie aan origineel: voltooid 26.11.19
# SENTENCE 55: invoer tweede collatie: gb
# SENTENCE 56: bespreking eindversie: gb
# SENTENCE 57: markeren annotaties: te doen / in bewerking / voltooid
# SENTENCE 58: gereed 17.4.2019
# SENTENCE 59: titel gecontroleerd 15.9.2020
# SENTENCE 60: personen getagd 12.10.2020
# SENTENCE 61: vertaling ingevoerd 16.2.2021
# SENTENCE 62: codering personen aangepast 16.2.2022
# SENTENCE 63: controle/aanpassing afkortingen en emendaties 21.4.2023
# SENTENCE 64: ​​
# ​
# ​
# ​
# SENTENCE 65: Lieve Zus,
# neem me niet kwalijk dat ik je zoo'n gekreukte enveloppe zend​, maar ik had geen meer in huis, en ik moest je toch even zeggen dat ik morgen middag helaas in 't museum bij 't ophangen van schilderijen moet zijn, omdat ik in de jury van S t Lucas ben.​
# SENTENCE 66: Ik ben er al een groot deel van de week geweest.
# SENTENCE 67: Ik woû je wel graag tusschen 4 - 5 even komen opzoeken, anders zie ik je weer in een week denkelijk niet, want ik ga met de Paaschdagen naar Arnhem.​Ik kom dus morgen even zien of je thuis ben.
# SENTENCE 68: Dag!
# SENTENCE 69: Veel beste groeten je Piet.
# SENTENCE 70: Dear Zus,
# I’m sorry I’m sending you such a crumpled envelope,​but I didn’t have any more in the house, and I had to tell you that unfortunately I have to be in the museum tomorrow afternoon when the paintings are hung because I’m on the St Lucas jury.​
# SENTENCE 71: I’ve already been there for a good part of the week.
# SENTENCE 72: I’d like to come and see you between 4 and 5, otherwise I don’t think I’ll see you again in a week, because I ‘m going to Arnhem for Easter.​So I’ll call round tomorrow to see if you’re home.
# SENTENCE 73: Bye!
# SENTENCE 74: With my very best wishes, your Piet.
# SENTENCE 75: Manuscript.
# SENTENCE 76: De brief dateert van kort voor Pasen 1909 (zie par. 3), dat op 8 april viel.
# SENTENCE 77: Omdat Mondriaan en De Iongh
# SENTENCE 78: doorgaans afspraken op donderdagen is het waarschijnlijk dat Mondriaan op de donderdag vóór Pasen wilde afspreken.
# SENTENCE 79: Daarom dateren we de brief op woensdag 7 april 1909.
# SENTENCE 80: ​
# SENTENCE 81: De envelop is niet overgeleverd.
# SENTENCE 82: Mondriaan was in 1903 toegetreden tot de zaalbeheercommissie van kunstenaarsvereniging Sint Lucas.
# SENTENCE 83: (Gorter 2017, p. 19).
# SENTENCE 84: De tentoonstelling die werd voorbereid was de 19e Jaarlijksche Tentoonstelling
# SENTENCE 85: , die plaatshad in het Stedelijk Museum
# SENTENCE 86: van 11 april tot 16 mei 1909.
# SENTENCE 87: In Arnhem bracht Mondriaan de paasdagen (zondag 11 en maandag 12 april) door bij zijn vader.
# SENTENCE 88: Om die reden kan hij de opening van de Sint Lucas-tentoonstelling
# SENTENCE 89: op zondag 11 april niet hebben bijgewoond.
# SENTENCE 90: ​
# SENTENCE 91: Brief aan Aletta de Iongh.
# SENTENCE 92: Amsterdam, tussen maandag 19 en vrijdag 23 april 1909.
# SENTENCE 93: Wietse Coppes
# SENTENCE 94: Leo Jansen
# SENTENCE 95: Mondriaan Editieproject
# SENTENCE 96: Nederland
# SENTENCE 97: Otterlo
# SENTENCE 98: Kröller Müller Museum
# SENTENCE 99: KM 120.999
# SENTENCE 100: 19090421y_IONG_1304

# %% [markdown]
# # Illustrations

# %%
results = A.search("""
rs type=artwork-m key~[0-9]
""")
# Out:
#   0.00s 12 results

# %%
A.show(results, withNodes=True,end=1)
# Out:
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/7&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304:7">proeftuin@19090421y_IONG_1304:7</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk:13686 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">standOff:15148 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">listAnnotation:14206 </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>typednotes</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14313 </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>transcrSource_NL</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:16028 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25275 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1484 </span> <span class="txtu"><span class=" is_note">Manuscript</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25276 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1485 </span> <span class="txtu"><span class=" is_note">.</span></span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25277 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1486 </span> <span class="txtu"><span class=" is_note"><br></span></span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14314 </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>dating_NL</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:16029 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25278 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1487 </span> <span class="txtu"><span class=" is_note">De </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25279 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1488 </span> <span class="txtu"><span class=" is_note">brief </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25280 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1489 </span> <span class="txtu"><span class=" is_note">dateert </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25281 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1490 </span> <span class="txtu"><span class=" is_note">van </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25282 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1491 </span> <span class="txtu"><span class=" is_note">vóór </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25283 </span></div><div class="childre ...

# %% [markdown]
# ## The first letter

# %%
A.pretty(F.otype.s("letter")[0], full=True, withNodes=False)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303">proeftuin@19090216y_IONG_1303</a></span></div><div class=" children"><div class="contnr c4    " ><div class="lbl c4  " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090216y_IONG_1303</span></span></span></div><div class="children hor wrap "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">?editem </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">​</span></div></div></div></div></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">teiHeader </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">fileDesc </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">titleStmt </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">title </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Brief </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">aan </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="features"><span class="type " ><span class="f">type=</span>person</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Aletta </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">de </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Iongh</span></span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">. </span></span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Amsterdam</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="tx ...

# %% [markdown]
# ## Pages

# %%
pages = A.search("""
page
""")
A.table(pages, end=2)
# Out:
#   0.00s 51 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">page</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/5&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:5">proeftuin@19090216y_IONG_1303:5</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx" ><span class="txtu">Beste </span><span class="txtu">Zus</span><span class="txtu">,</span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">​</span><span class="txtu">kom </span><span class="txtu">je </span><span class="txtu">morgenavond </span><span class="txtu">(</span><span class="txtu">Woensdag</span><span class="txtu">) </span><span class="txtu">om </span><span class="txtu">kwart </span><span class="txtu">voor </span><span class="txtu">acht </span><span class="txtu">ingang </span><span class="txtu">kleine </span><span class="txtu">zaal </span><span class="txtu">Concertgebouw</span><span class="txtu">​</span><span class="txtu">, </span><span class="txtu"> </span><span class="txtu">dan </span><span class="txtu">heb </span><span class="txtu">ik </span><span class="txtu">een </span><span class="txtu">plaats </span><span class="txtu">voor </span><span class="plain  r " ><span class="txtu">v </span></span><span class="txtu">​</span><span class="plain  l " ><span class="txtu">. </span></span><span class="txtu"> </span><span class="plain  r " ><span class="txtu">Bu</span></span><span class="txtu">l</span><span class="plain  l " ><span class="txtu">h</span><span class="txtu">lig </span><span class="txtu">voor </span><span class="txtu">je</span><span class="txtu">.</span><span class="txtu">​</span><span class="txtu">En </span><span class="txtu">dan </span><span class="txtu">kunnen </span><span class="txtu">we </span><span class="txtu">een </span><span class="txtu">andere </span><span class="txtu">dan </span><span class="txtu">Donderdagmiddag </span><span class="txtu">afspreken </span><span class="txtu">want </span><span class="txtu">dan </span><span class="txtu">kan </span><span class="txtu">ik </span><span class="txtu">niet </span><span class="txtu">goed</span><span class="txtu">.</span></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">Met </span><span class="txtu">vele </span><span class="txtu">beste </span><span class="txtu">groeten </span><span class="txtu">je </span><span class="txtu"><span class="r_underline ">Piet</span></span><span class="txtu"><span class="r_underline ">.</span></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/6&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:6">proeftuin@19090216y_IONG_1303:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx" ><span class="txtu">Dear </span><span class="txtu">Zus</span><span class="txtu">,</span><span class="txtu">​</span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">​</span><span class="txtu">If </span><span class="txtu">you </span><span class="txtu">come </span><span class="txtu">to </span><span class="txtu">the </span><span class="txtu">entrance </span><span class="txtu">to </span><span class="txtu">the </span><span class="txtu">small </span><span class="txtu">auditorium </span><span class="txtu">in </span><span class="txtu">the </span><span class="txtu">Concertgebouw </span><span class="txtu">at </span><span class="txtu">a </span><span class="txtu">quarter </span><span class="txtu">to </span><span class="txtu">eight </span><span class="txtu">tomorrow </span><span class="txtu">(</span><span class="txtu">Wednesday</span><span class="txtu">) </span><span class="txtu">evening</span><span class="txtu">, </span><span class="txtu">I </span><span class="txtu">have </span><span class="txtu">a </span><span class="txtu">ticket </span><span class="txtu">for </span><span class="txtu">van </span><span class="txtu">Buhlig </span><span class="txtu">for </span><span class="txtu">you</span><span class="txtu">.</span><span class="txtu">​</span><span class="txtu">And </span><span class="txtu">then </span><span class="txtu">we </span><span class="txtu">can </span><span class="txtu">arrange </span><span class="txtu">a </span><span class="txtu">time </span><span class="txtu">other </span><span class="txtu">than </span><span class="txtu">Thursday </span><span class="txtu">afternoon </span><span class="txtu">because </span><span class="txtu">I </span><span class="txtu">ca</span><span class="txtu">n’t </span><span class="txtu">manage </span><span class="txtu">that</span><span class="txtu">.</span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">With </span><span class="txtu">my </span><span class="txtu">very </span><span class="txtu">best </span><span class="txtu">wishes</span><span class="txtu">, </span><span class="txtu">your </span><span class="txtu"><span class="r_underline ">Piet</span></span><span class="txtu"><span class="r_underline ">.</span></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span></span></span></td></tr></table>

# %% [markdown]
# ## Overlapping divs

# %% [markdown]
# There are divs in divs
# Let's find them all.
#
# First the total amount of divs:

# %%
len(F.otype.s("div"))
# Out:
# 30

# %%
query = """
d1:div
&& d2:div

d1 < d2
"""

resultsA = A.search(query)
# Out:
#   0.01s 0 results

# %% [markdown]
# We can also find the divs that are directly under another div by means of the `parent` edges:

# %%
query = """
div
<parent- div
"""

resultsD = A.search(query)
# Out:
#   0.00s 0 results

# %% [markdown]
# So some divs are nested, but not directly below each other.
#
# Let's see which they are.

# %%
arbitrarily = set(resultsA)
directly = set(resultsD)

# %% [markdown]
# It is to be expected that the arbitrarily nested divs are a superset of the directly nested divs.

# %%
directly - arbitrarily
# Out:
# set()

# %% [markdown]
# Now the other way round:

# %%
results = arbitrarily - directly
results
# Out:
# set()

# %%
A.table(sorted(results), end=2)
# Out:
# <table></table>

# %%
query = """
div
<parent- div
<parent- div
"""
results = A.search(query)
# Out:
#   0.00s 0 results

# %%
from textwrap import dedent

# %%
for i in range(1, 5):
    query = dedent(
        f"""
        div
        -sibling>{i}> div
        """
    )

    print(f"div siblings at distance {i}")
    results = A.search(query)
# Out:
# div siblings at distance 1
#   0.00s 2 results
# div siblings at distance 2
#   0.00s 0 results
# div siblings at distance 3
#   0.00s 0 results
# div siblings at distance 4
#   0.00s 0 results

# %% [markdown]
# ### Notes

# %%
for (i, nn) in enumerate(F.otype.s("note")[4:5]):
    Apre.dm(f"### Note {i + 1}\n\n")
    tokens = L.d(nn, otype="token")
    s = L.u(L.d(nn, otype="token")[0], otype="chunk")[0]
    A.pretty(nn, withNodes=True, full=True)
    A.pretty(s, withNodes=True, full=True)
# Out:
# ### Note 1
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/7&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:7">proeftuin@19090216y_IONG_1303:7</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14306 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:16011 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25067 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">383 </span> <span class="txtu"><span class=" is_note">De </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25068 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">384 </span> <span class="txtu"><span class=" is_note">Amerikaanse </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25069 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">385 </span> <span class="txtu"><span class=" is_note">pianist </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs:14824 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25070 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">386 </span> <span class="txtu"><span class=" is_note">Richard </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25071 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">387 </span> <span class="txtu"><span class=" is_note">Moritz </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25072 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">388 </span> <span class="txtu"><span class=" is_note">Buhlig</span></span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25073 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">389 </span> <span class="txtu"><span class=" is_note"> </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25074 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">390 </span> <span class="txtu"><span class=" is_note">(</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25075 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">391 </span> <span class="txtu"><span class=" is_note">1880</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25076 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">392 </span> <span class="txtu"><span class=" is_note">-</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:25077 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">393 </span> <span class="txtu"><span class=" is_note">1952</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span c ...
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/7&amp;version=0.8.9" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:7">proeftuin@19090216y_IONG_1303:7</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk:13672 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">standOff:15146 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">listAnnotation:14200 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14302 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:16004 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24977 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">291 </span> <span class="txtu"><span class=" is_note">Manuscript</span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24978 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">292 </span> <span class="txtu"><span class=" is_note">.</span></span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24979 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">293 </span> <span class="txtu"><span class=" is_note"><br></span></span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14303 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:16005 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24980 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">294 </span> <span class="txtu"><span class=" is_note">De </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24981 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">295 </span> <span class="txtu"><span class=" is_note">brief </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24982 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">296 </span> <span class="txtu"><span class=" is_note">is </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24983 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">297 </span> <span class="txtu"><span class=" is_note">geschreven </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24984 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">298 </span> <span class="txtu"><span class=" is_note">op </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24985 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">299 </span> <span class="txtu"><span class=" is_note">een </span></span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">token:24986 </span></div><div class="children hor wra ...
