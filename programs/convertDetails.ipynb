# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Convert from TEI to TF
#
# We show how to convert a TEI data source into TF.
#
# This has two stages:
#
# 1. make an preliminary TF dataset with the character as slot type
# 1. feed the plain text to a tokenizer, and add tokens and sentences to the datset,
#    while removing its character and word nodes;
#    the new slot type is token.
#
# A dataset based on characters is precise, but rather inefficient.
# The second step makes the dataset much more efficient.

# %% [markdown]
# **More ways to do it!**
#
# * [convertExpress](convertExpress.ipynb) : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * *convertDetails*: run from Python with full control

# %% [markdown]
# ## Preliminary conversion
#
# Same as in [convertSteps](convertSteps.ipynb) but now with even more feedback.

# %% [markdown]
# ### Step 1: Check
#
# Check the input: validity of the TEI-XML.
#
# Make a report of the elements and attributes used.
#
# Use the declared schemas in the XML source to determine which elements have
# pure content and which ones mixed content.

# %%
# !python tfFromTei.py check ++verbose
# Out:
# TEI to TF checking: ~/github/annotation/mondriaan/tei/2023-03-20 => ~/github/annotation/mondriaan/report
# INFO: Needs af.xsd (exists)
# INFO: Needs ns2.xsd (exists)
# INFO: Needs ns1.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/mondriaan/schema/MD.xsd
# 	round   1:  49 changes
# 180 identical override(s)
#   6 changing override(s)
# 	address pure ==> mixed
# 	postmark complex mixed (added)
# 	rewrite complex mixed (added)
# 	sepLine complex pure (added)
# 	transpose pure ==> mixed
# 	wbh complex pure (added)
# Section model I
# Start folder proeftuin:
#   14 19100131_SAAL_ARNO_0018.xml
# End   folder proeftuin
#
# 217 info line(s) written to ~/github/annotation/mondriaan/report/elements.txt
# 0 error(s) in 0 file(s) written to ~/github/annotation/mondriaan/report/errors.txt
# 59 tags of which 0 with multiple namespaces written to ~/github/annotation/mondriaan/report/namespaces.txt

# %% [markdown]
# ### Step 2: Convert
#
# Run the actual conversin and produce TF output.

# %%
# !python tfFromTei.py convert ++verbose
# Out:
# TEI to TF converting: ~/github/annotation/mondriaan/tei/2023-03-20 => ~/github/annotation/mondriaan/tf/0.8.1pre
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/annotation/mondriaan/tf/0.8.1pre
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    folder, letter, chunk
#    |   SECTION   FEATURES: folder, letter, chunk
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       ch
#    |     0.00s OK
#    |     0.00s Following director...
# Start folder proeftuin:
#   14 19100131_SAAL_ARNO_0018.xml
# End   folder proeftuin
#
# source reading done
#    |     0.19s "edge" actions: 0
#    |     0.19s "feature" actions: 123262
#    |     0.19s "node" actions: 12921
#    |     0.19s "resume" actions: 0
#    |     0.19s "slot" actions: 63491
#    |     0.19s "terminate" actions: 12921
#    |          1 x "accMat" node
#    |          8 x "add" node
#    |          8 x "addrLine" node
#    |          5 x "address" node
#    |         28 x "altIdentifier" node
#    |         14 x "body" node
#    |          1 x "c" node
#    |        154 x "change" node
#    |      63491 x "char" node  = slot type
#    |         12 x "choice" node
#    |         86 x "chunk" node
#    |         31 x "closer" node
#    |         28 x "correspAction" node
#    |         14 x "correspDesc" node
#    |         14 x "country" node
#    |         16 x "date" node
#    |          9 x "dateline" node
#    |         14 x "decoDesc" node
#    |         14 x "decoNote" node
#    |          9 x "del" node
#    |         93 x "div" node
#    |         28 x "editor" node
#    |         14 x "facsimile" node
#    |         14 x "fileDesc" node
#    |          1 x "folder" node
#    |         52 x "graphic" node
#    |         81 x "hi" node
#    |         42 x "idno" node
#    |         14 x "institution" node
#    |         14 x "letter" node
#    |         14 x "msDesc" node
#    |         14 x "msIdentifier" node
#    |         28 x "name" node
#    |         86 x "note" node
#    |         14 x "objectDesc" node
#    |         29 x "opener" node
#    |         10 x "orig" node
#    |         95 x "p" node
#    |         51 x "pb" node
#    |         14 x "physDesc" node
#    |         14 x "placeName" node
#    |          2 x "postmark" node
#    |          6 x "postscript" node
#    |         14 x "profileDesc" node
#    |         76 x "ptr" node
#    |         14 x "publicationStmt" node
#    |         57 x "ref" node
#    |         10 x "reg" node
#    |         14 x "revisionDesc" node
#    |        172 x "rs" node
#    |         55 x "salute" node
#    |         14 x "settlement" node
#    |         31 x "signed" node
#    |         14 x "sourceDesc" node
#    |          9 x "space" node
#    |         14 x "sponsor" node
#    |         52 x "surface" node
#    |         14 x "teiHeader" node
#    |         14 x "text" node
#    |         14 x "title" node
#    |         14 x "titleStmt" node
#    |          4 x "unclear" node
#    |      11119 x "word" node
#    |      76412 nodes of all types
#    |     0.20s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.01s Sorting 1 nodes of type "accMat"
#    |     0.01s Sorting 8 nodes of type "add"
#    |     0.01s Sorting 8 nodes of type "addrLine"
#    |     0.01s Sorting 5 nodes of type "address"
#    |     0.01s Sorting 28 nodes of type "altIdentifier"
#    |     0.01s Sorting 14 nodes of type "body"
#    |     0.01s Sorting 1 nodes of type "c"
#    |     0.01s Sorting 154 nodes of type "change"
#    |     0.01s Sorting 12 nodes of type "choice"
#    |     0.01s Sorting 86 nodes of type "chunk"
#    |     0.01s Sorting 31 nodes of type "closer"
#    |     0.01s Sorting 28 nodes of type "correspAction"
#    |     0.01s Sorting 14 nodes of type "correspDesc"
#    |     0.01s Sorting 14 nodes of type "country"
#    |     0.01s Sorting 16 nodes of type "date"
#    |     0.01s Sorting 9 nodes of type "dateline"
#    |     0.01s Sorting 14 nodes of type "decoDesc"
#    |     0.01s Sorting 14 nodes of type "decoNote"
#    |     0.01s Sorting 9 nodes of type "del"
#    |     0.01s Sorting 93 nodes of type "div"
#    |     0.01s Sorting 28 nodes of type "editor"
#    |     0.01s Sorting 14 nodes of type "facsimile"
#    |     0.01s Sorting 14 nodes of type "fileDesc"
#    |     0.01s Sorting 1 nodes of type "folder"
#    |     0.01s Sorting 52 nodes of type "graphic"
#    |     0.01s Sorting 81 nodes of type "hi"
#    |     0.01s Sorting 42 nodes of type "idno"
#    |     0.01s Sorting 14 nodes of type "institution"
#    |     0.01s Sorting 14 nodes of type "letter"
#    |     0.02s Sorting 14 nodes of type "msDesc"
#    |     0.02s Sorting 14 nodes of type "msIdentifier"
#    |     0.02s Sorting 28 nodes of type "name"
#    |     0.02s Sorting 86 nodes of type "note"
#    |     0.02s Sorting 14 nodes of type "objectDesc"
#    |     0.02s Sorting 29 nodes of type "opener"
#    |     0.02s Sorting 10 nodes of type "orig"
#    |     0.02s Sorting 95 nodes of type "p"
#    |     0.02s Sorting 51 nodes of type "pb"
#    |     0.02s Sorting 14 nodes of type "physDesc"
#    |     0.02s Sorting 14 nodes of type "placeName"
#    |     0.02s Sorting 2 nodes of type "postmark"
#    |     0.02s Sorting 6 nodes of type "postscript"
#    |     0.02s Sorting 14 nodes of type "profileDesc"
#    |     0.02s Sorting 76 nodes of type "ptr"
#    |     0.02s Sorting 14 nodes of type "publicationStmt"
#    |     0.02s Sorting 57 nodes of type "ref"
#    |     0.02s Sorting 10 nodes of type "reg"
#    |     0.02s Sorting 14 nodes of type "revisionDesc"
#    |     0.02s Sorting 172 nodes of type "rs"
#    |     0.02s Sorting 55 nodes of type "salute"
#    |     0.02s Sorting 14 nodes of type "settlement"
#    |     0.02s Sorting 31 nodes of type "signed"
#    |     0.02s Sorting 14 nodes of type "sourceDesc"
#    |     0.02s Sorting 9 nodes of type "space"
#    |     0.02s Sorting 14 nodes of type "sponsor"
#    |     0.02s Sorting 52 nodes of type "surface"
#    |     0.02s Sorting 14 nodes of type "teiHeader"
#    |     0.02s Sorting 14 nodes of type "text"
#    |     0.02s Sorting 14 nodes of type "title"
#    |     0.02s Sorting 14 nodes of type "titleStmt"
#    |     0.02s Sorting 4 nodes of type "unclear"
#    |     0.02s Sorting 11119 nodes of type "word"
#    |     0.04s Max node = 76412
#    |     0.04s OK
#    |     0.00s reassigning feature values ...
#    |      |     0.00s node feature "after" with 11119 nodes
#    |      |     0.00s node feature "ch" with 63491 nodes
#    |      |     0.01s node feature "chunk" with 86 nodes
#    |      |     0.01s node feature "dim" with 9 nodes
#    |      |     0.01s node feature "empty" with 404 nodes
#    |      |     0.01s node feature "extraspace" with 823 nodes
#    |      |     0.01s node feature "f" with 35 nodes
#    |      |     0.01s node feature "facs" with 37 nodes
#    |      |     0.01s node feature "folder" with 1 node
#    |      |     0.01s node feature "form" with 14 nodes
#    |      |     0.01s node feature "id" with 125 nodes
#    |      |     0.01s node feature "is_meta" with 10460 nodes
#    |      |     0.01s node feature "is_note" with 24591 nodes
#    |      |     0.01s node feature "key" with 138 nodes
#    |      |     0.01s node feature "lang" with 75 nodes
#    |      |     0.01s node feature "letter" with 14 nodes
#    |      |     0.01s node feature "n" with 90 nodes
#    |      |     0.01s node feature "quantity" with 9 nodes
#    |      |     0.01s node feature "reason" with 2 nodes
#    |      |     0.01s node feature "rend" with 94 nodes
#    |      |     0.01s node feature "rend_above" with 9 nodes
#    |      |     0.01s node feature "rend_below" with 1 node
#    |      |     0.01s node feature "rend_blockletter" with 34 nodes
#    |      |     0.01s node feature "rend_center" with 6 nodes
#    |      |     0.01s node feature "rend_inline" with 3 nodes
#    |      |     0.01s node feature "rend_italics" with 707 nodes
#    |      |     0.01s node feature "rend_norend" with 4 nodes
#    |      |     0.01s node feature "rend_overwritten" with 2 nodes
#    |      |     0.01s node feature "rend_right" with 6 nodes
#    |      |     0.01s node feature "rend_right_underline" with 6 nodes
#    |      |     0.01s node feature "rend_spaced" with 38 nodes
#    |      |     0.01s node feature "rend_super" with 12 nodes
#    |      |     0.01s node feature "rend_super_underline" with 1 node
#    |      |     0.01s node feature "rend_super_underline2" with 2 nodes
#    |      |     0.01s node feature "rend_underline" with 259 nodes
#    |      |     0.01s node feature "rend_underline2" with 9 nodes
#    |      |     0.01s node feature "rend_upsidedown" with 90 nodes
#    |      |     0.01s node feature "str" with 11119 nodes
#    |      |     0.01s node feature "target" with 127 nodes
#    |      |     0.01s node feature "type" with 465 nodes
#    |      |     0.01s node feature "unit" with 9 nodes
#    |      |     0.01s node feature "url" with 52 nodes
#    |      |     0.01s node feature "when" with 14 nodes
#    |      |     0.01s node feature "who" with 113 nodes
#    |     0.01s OK
#   0.00s Exporting 45 node and 1 edge and 1 config features to ~/github/annotation/mondriaan/tf/0.8.1pre:
#   0.00s VALIDATING oslots feature
#   0.00s VALIDATING oslots feature
#   0.00s maxSlot=      63491
#   0.00s maxNode=      76412
#   0.00s OK: oslots is valid
#    |     0.00s T after                to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.02s T ch                   to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T chunk                to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T dim                  to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T empty                to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T extraspace           to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T f                    to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T facs                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T folder               to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T form                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T id                   to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T is_meta              to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.01s T is_note              to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T key                  to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T lang                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T letter               to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T n                    to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.01s T otype                to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T quantity             to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T reason               to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_above           to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_below           to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_blockletter     to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_center          to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_inline          to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_italics         to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_norend          to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_overwritten     to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_right           to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_right_underline to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_spaced          to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_super           to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_super_underline to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_super_underline2 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_underline       to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_underline2      to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T rend_upsidedown      to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T str                  to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T target               to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T type                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T unit                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T url                  to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T when                 to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T who                  to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.03s T oslots               to ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s M otext                to ~/github/annotation/mondriaan/tf/0.8.1pre
#   0.08s Exported 45 node features and 1 edge features and 1 config features to ~/github/annotation/mondriaan/tf/0.8.1pre

# %% [markdown]
# ### Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and precomputations are performed.
# Next time the loading will be much quicker.

# %%
# !python tfFromTei.py load ++verbose
# Out:
#    |     0.02s T otype                from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.20s T oslots               from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T folder               from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.13s T ch                   from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T chunk                from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |     0.00s T letter               from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.40s C __order__            from otype, oslots, __levels__
#    |      |     0.01s C __rank__             from otype, __order__
#    |      |     0.43s C __levUp__            from otype, oslots, __rank__
#    |      |     0.11s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.01s C __characters__       from otext
#    |      |     0.14s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, letter, chunk
#    |      |     0.02s T after                from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T dim                  from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T empty                from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T extraspace           from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T f                    from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T facs                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T form                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T id                   from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.02s T is_meta              from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.05s T is_note              from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T key                  from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T lang                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T n                    from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T quantity             from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T reason               from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_above           from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_below           from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_blockletter     from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_center          from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_inline          from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_italics         from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_norend          from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_overwritten     from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_right           from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_right_underline from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_spaced          from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_super           from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_super_underline from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_super_underline2 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_underline       from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_underline2      from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T rend_upsidedown      from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.03s T str                  from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T target               from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T type                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T unit                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T url                  from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T when                 from ~/github/annotation/mondriaan/tf/0.8.1pre
#    |      |     0.00s T who                  from ~/github/annotation/mondriaan/tf/0.8.1pre
# max node = 76412

# %% [markdown]
# ### Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
# !python tfFromTei.py app +force ++verbose
# Out:
# App updating  ...
# 	about  : exists , generated ~/github/annotation/mondriaan/docs/about.md
# 	trans  : exists , generated ~/github/annotation/mondriaan/docs/transcription.md
# 	display: exists , generated ~/github/annotation/mondriaan/app/static/display.css
# 	config : exists , generated ~/github/annotation/mondriaan/app/config.yaml
# 	app    : exists , generated ~/github/annotation/mondriaan/app/app.py
# Done

# %% [markdown]
# ## View the preliminary result
#
# As a final proof, we load the app:

# %%
from tf.app import use

# %%
ORG = "annotation"
REPO = "mondriaan"

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.1pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.1pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>63491.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>4535.07</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>3880.00</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>3880.00</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>86</td>
#     <td>738.26</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>93</td>
#     <td>1013.75</td>
#     <td><i>148</i></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>646.64</td>
#     <td>14</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>368.07</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>95</td>
#     <td>324.60</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>250.83</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>86</td>
#     <td>247.10</td>
#     <td>33</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>204.50</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>117.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>76.93</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>68.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>31</td>
#     <td>50.42</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>35.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>154</td>
#     <td>33.46</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>5</td>
#     <td>31.20</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>27.75</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>24.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>55</td>
#     <td>21.96</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>20.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>9</td>
#     <td>16.22</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>15.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>29</td>
#     <td>15.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>8</td>
#     <td>13.88</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>172</td>
#     <td>13.79</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>57</td>
#     <td>13.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>13.02</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>12.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>12</td>
#     <td>12.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>81</td>
#     <td>11.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>11.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>9.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>31</td>
#     <td>8.74</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>7.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>7.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>7.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>10</td>
#     <td>6.90</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>6.86</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>10</td>
#     <td>6.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>4.78</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>11119</td>
#     <td>4.52</td>
#     <td>79</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>52</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>c</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>52</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>51</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>76</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>63491</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/ch.tf">ch</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the unicode character of a slot</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/dim.tf">dim</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute dim</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotati
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 26 artwork-ms<br>

# %% [markdown]
# ### Show a fragment

# %%
chunk = Apre.api.F.otype.s("chunk")[4]
Apre.plain(chunk)
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/5&amp;version=0.8.1pre" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:5">proeftuin@19090216y_IONG_1303:5</a></span></span>  <span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">B</span><span class="txtu">e</span><span class="txtu">s</span><span class="txtu">t</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">Z</span><span class="txtu">u</span><span class="txtu">s</span><span class="txtu">,</span><span class="txtu"></span><span class="break"><br></span><span class="txtu"></span><span class="txtu">​</span><span class="txtu">k</span><span class="txtu">o</span><span class="txtu">m</span><span class="txtu"> </span><span class="txtu">j</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">m</span><span class="txtu">o</span><span class="txtu">r</span><span class="txtu">g</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu">a</span><span class="txtu">v</span><span class="txtu">o</span><span class="txtu">n</span><span class="txtu">d</span><span class="txtu"> </span><span class="txtu">(</span><span class="txtu">W</span><span class="txtu">o</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu">s</span><span class="txtu">d</span><span class="txtu">a</span><span class="txtu">g</span><span class="txtu">)</span><span class="txtu"> </span><span class="txtu">o</span><span class="txtu">m</span><span class="txtu"> </span><span class="txtu">k</span><span class="txtu">w</span><span class="txtu">a</span><span class="txtu">r</span><span class="txtu">t</span><span class="txtu"> </span><span class="txtu">v</span><span class="txtu">o</span><span class="txtu">o</span><span class="txtu">r</span><span class="txtu"> </span><span class="txtu">a</span><span class="txtu">c</span><span class="txtu">h</span><span class="txtu">t</span><span class="txtu"> </span><span class="txtu">i</span><span class="txtu">n</span><span class="txtu">g</span><span class="txtu">a</span><span class="txtu">n</span><span class="txtu">g</span><span class="txtu"> </span><span class="txtu">k</span><span class="txtu">l</span><span class="txtu">e</span><span class="txtu">i</span><span class="txtu">n</span><span class="txtu">e</span><span class="txtu"> </span><span class="txtu">z</span><span class="txtu">a</span><span class="txtu">a</span><span class="txtu">l</span><span class="txtu"> </span><span class="txtu">C</span><span class="txtu">o</span><span class="txtu">n</span><span class="txtu">c</span><span class="txtu">e</span><span class="txtu">r</span><span class="txtu">t</span><span class="txtu">g</span><span class="txtu">e</span><span class="txtu">b</span><span class="txtu">o</span><span class="txtu">u</span><span class="txtu">w</span><span class="txtu"> </span><span class="txtu">C</span><span class="txtu">o</span><span class="txtu">n</span><span class="txtu">c</span><span class="txtu">e</span><span class="txtu">r</span><span class="txtu">t</span><span class="txtu">-</span><span class="txtu">g</span><span class="txtu">e</span><span class="txtu">b</span><span class="txtu">o</span><span class="txtu">u</span><span class="txtu">w</span><span class="txtu">,</span><span class="txtu"> </span><span class="txtu"> </span><span class="txtu">d</span><span class="txtu">a</span><span class="txtu">n</span><span class="txtu"> </span><span class="txtu">h</span><span class="txtu">e</span><span class="txtu">b</span><span class="txtu"> </span><span class="txtu">i</span><span class="txtu">k</span><span class="txtu"> </span><span class="txtu">e</span><span class="txtu">e</span><span class="txtu">n</span><span class="txtu"> </span><span class="txtu">p</span><span class="txtu">l</span><span class="txtu">a</span><span class="txtu">a</span><span class="txtu">t</span><span class="txtu">s</span ...

# %% [markdown]
# ## Add tokens and sentences
#
# We add tokens and sentences to the TF dataset.
#
# We do this by the following steps
#
# 1. Generate a plain text plus mapping between character positions and nodes
# 2. Use Spacy to tokenize the text and to determine sentence boundaries
# 3. translate the Spacy results back to extra nodes and features for the TF set
# 4. replace the character slots in the TF set by tokens

# %% [markdown]
# ### Step by step from Python
#
# We carry out the steps from within Python.
#
# In that way we get access to all intermediate results, and we can play and explore between the steps.
#
# We load the data we have so far, and pass it on to an `NLPipeline` object, defined by Text-Fabric.

# %%
from tf.app import use
from tf.convert.addnlp import NLPipeline

# %%
ORG = "annotation"
REPO = "mondriaan"

# %% [markdown]
# ### Back to the previous state
#
# When we have added the data to the dataset, we will tweak the TF app.
#
# But if we want to redo the pipeline, we have to restore the app to the situation before
# the tokens and sentences were added.
#
# That's the reason we have the next cell.

# %%
# !python tfFromtei.py app +force ++verbose
# Out:
# App updating  ...
# 	about  : exists , generated ~/github/annotation/mondriaan/docs/about.md
# 	trans  : exists , generated ~/github/annotation/mondriaan/docs/transcription.md
# 	display: exists , generated ~/github/annotation/mondriaan/app/static/display.css
# 	config : exists , generated ~/github/annotation/mondriaan/app/config.yaml
# 	app    : exists , generated ~/github/annotation/mondriaan/app/app.py
# Done

# %%
Apre = use(f"{ORG}/{REPO}:clone", checkout="clone")
NLP = NLPipeline()
NLP.loadApp(Apre)
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.1pre</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.1pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>63491.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>4535.07</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>3880.00</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>3880.00</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>86</td>
#     <td>738.26</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>93</td>
#     <td>1013.75</td>
#     <td><i>148</i></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>646.64</td>
#     <td>14</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>368.07</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>95</td>
#     <td>324.60</td>
#     <td>49</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>250.83</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>86</td>
#     <td>247.10</td>
#     <td>33</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>204.50</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>117.14</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>86.36</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>76.93</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>71.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>68.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>31</td>
#     <td>50.42</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>35.54</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>154</td>
#     <td>33.46</td>
#     <td>8</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>5</td>
#     <td>31.20</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>27.75</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>24.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>55</td>
#     <td>21.96</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>20.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>9</td>
#     <td>16.22</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>15.54</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>29</td>
#     <td>15.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>8</td>
#     <td>13.88</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>172</td>
#     <td>13.79</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>57</td>
#     <td>13.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>13.02</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>12.50</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>12</td>
#     <td>12.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>81</td>
#     <td>11.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>11.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>10.21</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>9.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>9.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>9.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>31</td>
#     <td>8.74</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>7.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>7.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>7.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>10</td>
#     <td>6.90</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>6.86</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>10</td>
#     <td>6.60</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>4.78</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>11119</td>
#     <td>4.52</td>
#     <td>79</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>52</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>c</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>52</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>51</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>76</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>63491</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/ch.tf">ch</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the unicode character of a slot</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1pre/dim.tf">dim</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute dim</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotati
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 26 artwork-ms<br>

# %% [markdown]
# ### Before the steps
#
# We can set the verbosity as we like.
#
# We store the settings in two variables that we will pass to the following steps.
#
# Return to the next cell, change the value for `verbose` and or `write`, run it,
# and from then on all the next steps will react to the new settings.

# %% [markdown]
# Generate plain text (add `verbose=-1` or `0` or `1` and/or `write=True` if you like).
#
# * `verbose=-1` is the same as `-verbose`
# * `verbose=0` is the same as `+verbose`
# * `verbose=1` is the same as `++verbose`

# %%
verbose = 0
write=True

# %% [markdown]
# ### Step 1: Generate a plain text of the whole corpus
#
# The function delivers the text in a variable, and it has recorded which character positions correspond
# to which slots in the TF dataset.
#
# We receive both items of data.

# %%
(text, positions) = NLP.task(plaintext=True, verbose=verbose, write=write)
# Out:
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 202 empty slots
#    |   recorded flow MAIN       with 127616 items
#    |   recorded flow del        with    159 items
#    |   recorded flow note       with  64164 items
#    |   recorded flow orig       with    227 items
#   0.19s Done. Generated text and positions written to ~/github/annotation/mondriaan/_temp/txt/plain.txt

# %% [markdown]
# ### Step 2: Run Spacy to get tokens and sentences
#
# Now we feed the text from step 1 into the NLP pipeline, which is Spacy.
#
# We get a list of tokens and a list of sentences back.

# %%
(tokens, sentences) = NLP.task(lingo=True, text=text, verbose=verbose, write=write)
# Out:
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
#   0.00s Using NLP pipeline Spacy (may take a while)...
#   2.63s NLP done

# %% [markdown]
# Let's examine a few tokens and sentences:

# %%
for token in tokens[400:410]:
    print(token)
# Out:
# (1644, 1646, 'to', ' ')
# (1647, 1650, 'the', ' ')
# (1651, 1659, 'entrance', ' ')
# (1660, 1662, 'to', ' ')
# (1663, 1666, 'the', ' ')
# (1667, 1672, 'small', ' ')
# (1673, 1683, 'auditorium', ' ')
# (1684, 1686, 'in', ' ')
# (1687, 1690, 'the', ' ')
# (1691, 1704, 'Concertgebouw', ' ')

# %% [markdown]
# Each token entry specifies the start and end position in the plain text file,
# the string value of the token, and the whitespace after the token, if any.

# %%
for sentence in sentences[390:410]:
    print(sentence)
# Out:
# (8493, 8583, 'Als je om kwart voor 8 niet bij me ben, denk ik, dat je verhinderd was, en ga de deur uit.')
# (8583, 8588, 'Dag!')
# (8589, 8620, 'hartelijke groeten van je Piet.')
# (8620, 8627, ' xxx.')
# (8627, 8638, 'END chunk.')
# (8638, 8652, 'BEGIN chunk.')
# (8652, 8759, 'Dear Zus,The polyp didn’t come yesterday morning, but I found his card in the letterbox in the evening.')
# (8760, 8781, 'I shall write to him.')
# (8782, 8821, 'It’s fine for you to come on Wednesday.')
# (8822, 8952, 'The theosophical lectures are open to everyone on Tuesdays, apart from the first Tuesday of every month: then only to the members.')
# (8952, 9023, '￮ So if you want to come and pick me up around seven thirty, we can go.')
# (9024, 9110, 'If you aren’t with me by a quarter to eight I’ll assume you can’t come and I’ll leave.')
# (9110, 9115, 'Bye!')
# (9116, 9143, 'Warm wishes from your Piet.')
# (9143, 9150, ' xxx.')
# (9150, 9161, 'END chunk.')
# (9161, 9174, 'BEGIN META.')
# (9174, 9188, 'BEGIN chunk.')
# (9188, 9199, 'fileDesc.')
# (9200, 9210, 'titleStmt.')

# %% [markdown]
# Sentence entries have the same fields, except for the last whitespace field.
#
# Actually, the program will not use the texts of tokens and sentences for display, only for determining
# where the boundaries are.
#
# With those boundaries in hand, the texts of tokens and sentences are read off from the original corpus.

# %% [markdown]
# ### Step 3: Ingest the results in the data set
#
# A lot of critical things happen when we ingest the token and sentence streams into our dataset.
#
# We calculate slot positions, retrieve text, split some tokens, and last but not least,
# we replace the character-by-character basis of the preliminary dataset by a token-by-token basis.

# %%
newVersion = NLP.task(
    ingest=True,
    positions=positions,
    tokens=tokens,
    sentences=sentences,
    verbose=0,
    write=write,
)
# Out:
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
#   0.00s Ingesting tokens and sentences into the dataset ...
#    |     0.02s Mapping NLP data to nodes and features ...
#    |      |     0.00s generating token-nodes with features str, after, empty
#    |      |      |     0.00s 13761 token nodes have values assigned for str, after
#    |      |      |     0.00s 202 empty slots have split surrounding tokens
#    |      |      |     0.00s 336 space slots have split into chars
#    |      |      |     0.00s  3383x Items contained in extra generated text
#    |      |     0.04s 13761 tokens
#    |      |     0.04s generating sentence-nodes with features nsent
#    |      |      |     0.01s 756 sentence nodes have values assigned for nsent
#    |      |      |     0.02s   455x Items contained in extra generated text
#    |      |      |     0.02s   402x Items with empty final text
#    |      |     0.05s 756 sentences
#    |     0.07s Make a modified dataset ...
#   0.00s Feature overview: 45 for nodes; 1 for edges; 1 configs; 9 computed
#    |     0.32s Done
#   0.31s Enriched data is available in version 0.8.1
# You may need to adapt this TF app and its documentation:
# please run: python tfFromTei.py apptoken

# %% [markdown]
# ### Step 4: Adjust the app to the modified dataset
#
# Various things in the `config.yaml` and `app.py` of the TF app should be updated, as well
# as the documentation file that gives the ins and outs of the resulting features.

# %%
# !python tfFromTei.py apptoken +force ++verbose
# Out:
# App updating  adapted to tokens and sentences ...
# 	about  : exists , generated ~/github/annotation/mondriaan/docs/about.md
# 	trans  : exists , generated ~/github/annotation/mondriaan/docs/transcription.md
# 	display: exists , generated ~/github/annotation/mondriaan/app/static/display.css
# 	config : exists , generated ~/github/annotation/mondriaan/app/config.yaml
# 	app    : exists , generated ~/github/annotation/mondriaan/app/app.py
# Done

# %% [markdown]
# # Use the new dataset
#
# We can now use the resulting dataset in the usual way.
# Because we have adapted the TF app, the version without the `pre` will now be loaded.

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.1</span>
#    |     0.01s T otype                from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.04s T oslots               from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T letter               from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.03s T str                  from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T chunk                from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T folder               from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.03s T after                from ~/github/annotation/mondriaan/tf/0.8.1
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.09s C __order__            from otype, oslots, __levels__
#    |      |     0.00s C __rank__             from otype, __order__
#    |      |     0.09s C __levUp__            from otype, oslots, __rank__
#    |      |     0.02s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.00s C __characters__       from otext
#    |      |     0.03s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, letter, chunk
#    |     0.00s T dim                  from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T empty                from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T extraspace           from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T f                    from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T facs                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T form                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T id                   from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T is_meta              from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.01s T is_note              from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T key                  from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T lang                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T n                    from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T nsent                from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T quantity             from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T reason               from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_above           from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_below           from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_blockletter     from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_center          from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_inline          from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_italics         from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_overwritten     from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_right           from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_right_underline from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_spaced          from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_super           from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_super_underline from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_super_underline2 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_underline       from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_underline2      from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T rend_upsidedown      from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T target               from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T type                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T unit                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T url                  from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T when                 from ~/github/annotation/mondriaan/tf/0.8.1
#    |     0.00s T who                  from ~/github/annotation/mondriaan/tf/0.8.1
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/about.md" title="provenance of annotation - mondriaan/tf">annotation - mondriaan 0.8.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="annotation - mondriaan feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>1</td>
#     <td>13761.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>14</td>
#     <td>982.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>14</td>
#     <td>849.93</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>14</td>
#     <td>849.93</td>
#     <td>86</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>86</td>
#     <td>160.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>93</td>
#     <td>219.99</td>
#     <td><i>149</i></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>14</td>
#     <td>124.57</td>
#     <td>13</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>95</td>
#     <td>73.39</td>
#     <td>51</td>
# </tr>
#
# <tr>
#     <th>postscript</th>
#     <td>6</td>
#     <td>62.83</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>revisionDesc</th>
#     <td>14</td>
#     <td>61.00</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>86</td>
#     <td>49.66</td>
#     <td>31</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>14</td>
#     <td>45.07</td>
#     <td>5</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>14</td>
#     <td>24.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>14</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>14</td>
#     <td>20.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>14</td>
#     <td>15.86</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>14</td>
#     <td>15.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>14</td>
#     <td>15.07</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>closer</th>
#     <td>31</td>
#     <td>12.71</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>756</td>
#     <td>11.72</td>
#     <td>64</td>
# </tr>
#
# <tr>
#     <th>address</th>
#     <td>5</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>28</td>
#     <td>7.75</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>14</td>
#     <td>7.43</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>16</td>
#     <td>5.81</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>change</th>
#     <td>154</td>
#     <td>5.55</td>
#     <td>6</td>
# </tr>
#
# <tr>
#     <th>salute</th>
#     <td>55</td>
#     <td>5.13</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>opener</th>
#     <td>29</td>
#     <td>4.97</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>dateline</th>
#     <td>9</td>
#     <td>4.22</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>physDesc</th>
#     <td>14</td>
#     <td>4.14</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>14</td>
#     <td>3.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>28</td>
#     <td>3.39</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>choice</th>
#     <td>12</td>
#     <td>3.17</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>addrLine</th>
#     <td>8</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>decoDesc</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>28</td>
#     <td>3.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sponsor</th>
#     <td>14</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>signed</th>
#     <td>31</td>
#     <td>2.61</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>14</td>
#     <td>2.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>172</td>
#     <td>2.39</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>42</td>
#     <td>2.33</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>81</td>
#     <td>2.27</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>57</td>
#     <td>2.25</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>decoNote</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>14</td>
#     <td>2.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>accMat</th>
#     <td>1</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>28</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>country</th>
#     <td>14</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>reg</th>
#     <td>10</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>52</td>
#     <td>2.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>del</th>
#     <td>9</td>
#     <td>1.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>orig</th>
#     <td>10</td>
#     <td>1.40</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>add</th>
#     <td>8</td>
#     <td>1.12</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>c</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>52</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>objectDesc</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>50</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>postmark</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>76</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>14</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>9</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>unclear</th>
#     <td>4</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>token</i></th>
#     <td>13761</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>annotation - mondriaan/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1/dim.tf">dim</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is TEI attribute dim</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/blob/main/tf/docs/transcription.md" title="~/github/annotation/mondriaan/tf/0.8.1/empty.tf">empty</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether a slot has been inserted in an empty element</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/annotation/mondriaan/
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/illustrations</span>
# Found 26 artwork-ms<br>

# %% [markdown]
# # Exploration
#
# We walk around a bit more in the corpus.

# %% [markdown]
# ## All titles:

# %%
for t in F.otype.s("titleStmt"):
    print(t, T.text(t))
# Out:
# 15545 Brief aan Aletta de Iongh. Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15546 Brief aan Aletta de Iongh. Amsterdam, woensdag 7 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15547 Brief aan Aletta de Iongh. Amsterdam, tussen maandag 19 en vrijdag 23 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15548 Brief aan Aletta de Iongh. Amsterdam, maandag 26 april 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15549 Brief aan Aletta de Iongh. Amsterdam, donderdag 13 mei 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15550 Brief aan Aletta de Iongh. Amsterdam, donderdag 24 juni 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15551 Brief aan Aletta de Iongh. Amsterdam, eerste helft augustus 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15552  Briefkaart aan Gerrit Willem Knap. Zoutelande, c. dinsdag 24 augustus 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15553 Brief aan Aletta de Iongh. Domburg, begin september 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15554 Brief aan Israël Querido. Domburg, september 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15555 Briefkaart aan Kees Spoor. Amsterdam, zondag 24 oktober 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15556 Brief aan Aletta de Iongh. Amsterdam, tussen 18 en 31 oktober 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15557 Brief aan Aletta de Iongh. Amsterdam, tussen dinsdag 19 oktober en c. woensdag 3 november 1909.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject
#
# 15558 Brief aan​. Amsterdam, maandag 31 januari 1910.
# Wietse Coppes
# Leo Jansen
# Mondriaan Editieproject

# %% [markdown]
# ## Sentences

# %%
for s in F.otype.s("sentence")[2:4]:
    print(T.text(s))
# Out:
# Wietse Coppes
# Leo Jansen

# %%
for s in F.otype.s("sentence")[2:4]:
    A.pretty(s, withNodes=True)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15565 </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">editor:14321 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">23 </span> <span class="txtu"><span class=" is_meta">Wietse </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">24 </span> <span class="txtu"><span class=" is_meta">Coppes</span></span></div></div></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:1">proeftuin@19090216y_IONG_1303:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15566 </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">editor:14322 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">26 </span> <span class="txtu"><span class=" is_meta">Leo </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">27 </span> <span class="txtu"><span class=" is_meta">Jansen</span></span></div></div></div></div></div></div></div>

# %%
for (i, s) in enumerate(F.otype.s("sentence")[0:100]):
    print(f"SENTENCE {i + 1}: {T.text(s)}")
# Out:
# SENTENCE 1: Brief aan Aletta de Iongh.
# SENTENCE 2: Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# SENTENCE 3: Wietse Coppes
# SENTENCE 4: Leo Jansen
# SENTENCE 5: Mondriaan Editieproject
# SENTENCE 6: Nederland
# SENTENCE 7: Otterlo
# SENTENCE 8: Kröller Müller Museum
# SENTENCE 9: KM 123.397
# SENTENCE 10: 19090216y_IONG_1303
# SENTENCE 11: ​
# SENTENCE 12: ​
# SENTENCE 13: ​
# SENTENCE 14: Piet Mondriaan
# SENTENCE 15: dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909
# SENTENCE 16: Amsterdam
# SENTENCE 17: Aletta de Iongh
# SENTENCE 18: transcriptie: voltooid 20.7.15
# SENTENCE 19: collatie bron: 6.6.16
# SENTENCE 20: tweede collatie aan het origineel: voltooid 26.11.19
# SENTENCE 21: invoer tweede collatie: voltooid 5.8.16
# SENTENCE 22: bespreking eindversie: gb
# SENTENCE 23: markeren annotaties: in bewerking / voltooid
# SENTENCE 24: gereed 17.4.2019
# SENTENCE 25: titel gecontroleerd 21.09.2020
# SENTENCE 26: personen getagd 12.10.2020
# SENTENCE 27: vertaling ingevoerd 16.2.2021
# SENTENCE 28: codering personen aangepast 16.2.2022
# SENTENCE 29: ​
# ​
# ​
# ​
# SENTENCE 30: Beste Zus,
# ​kom je morgenavond (Woensdag) om kwart voor acht ingang kleine zaal Concert-gebouw,  dan heb ik een plaats voor v.  Buhlig voor je.
# SENTENCE 31: ​En dan kunnen we een andere dan Donderdagmiddag afspreken want dan kan ik niet goed.
# SENTENCE 32: Met vele beste groeten je Piet.
# SENTENCE 33: ​
# Dear Zus,​
# If you come to the entrance to the small auditorium in the Concertgebouw at a quarter to eight tomorrow (Wednesday) evening, I have a ticket for van Buhlig for you.[2] And then we can arrange a time other than Thursday afternoon because I can’t manage that.
# SENTENCE 34: With my very best wishes, your Piet.
# SENTENCE 35: Brief aan Aletta de Iongh.
# SENTENCE 36: Amsterdam, woensdag 7 april 1909.
# SENTENCE 37: Wietse Coppes
# SENTENCE 38: Leo Jansen
# SENTENCE 39: Mondriaan Editieproject
# SENTENCE 40: Nederland
# SENTENCE 41: Otterlo
# SENTENCE 42: Kröller Müller Museum
# SENTENCE 43: KM 122.574
# SENTENCE 44: 19090407y_IONG_1739
# SENTENCE 45: ​
# SENTENCE 46: ​
# SENTENCE 47: ​
# SENTENCE 48: Piet Mondriaan
# SENTENCE 49: woensdag 7 april 1909
# SENTENCE 50: Amsterdam
# SENTENCE 51: Aletta de Iongh
# SENTENCE 52: transcriptie: voltooid 18.8.16
# SENTENCE 53: collatie bron: voltooid 18.8.16
# SENTENCE 54: tweede collatie aan origineel: voltooid 26.11.19
# SENTENCE 55: invoer tweede collatie: gb
# SENTENCE 56: bespreking eindversie: gb
# SENTENCE 57: markeren annotaties: te doen / in bewerking / voltooid
# SENTENCE 58: gereed 17.4.2019
# SENTENCE 59: titel gecontroleerd 15.9.2020
# SENTENCE 60: personen getagd 12.10.2020
# SENTENCE 61: vertaling ingevoerd 16.2.2021
# SENTENCE 62: codering personen aangepast 16.2.2022
# SENTENCE 63: ​
# ​
# ​
# ​
# SENTENCE 64: Lieve Zus,
# neem me niet kwalijk dat ik je zoo'n gekreukte enveloppe zend​, maar ik had geen meer in huis, en ik moest je toch even zeggen dat ik morgen middag helaas in 't museum bij 't ophangen van schilderijen moet zijn, omdat ik in de jury van St Lucas ben.
# SENTENCE 65: ​
# Ik ben er al een groot deel van de week geweest.
# SENTENCE 66: Ik woû je wel graag tusschen 4 - 5 even komen opzoeken, anders zie ik je weer in een week denkelijk niet, want ik ga met de Paaschdagen naar Arnhem.
# SENTENCE 67: ​Ik kom dus morgen even zien of je thuis ben.
# SENTENCE 68: Dag!
# SENTENCE 69: Veel beste groeten je Piet.
# SENTENCE 70: ​
# Dear Zus,
# I’m sorry I’m sending you such a crumpled envelope, ​but I didn’t have any more in the house, and I had to tell you that unfortunately I have to be in the museum tomorrow afternoon when the paintings are hung because I’m on the St Lucas jury.
# SENTENCE 71: ​
# I’ve already been there for a good part of the week.
# SENTENCE 72: I’d like to come and see you between 4 and 5, otherwise I don’t think I’ll see you again in a week, because I ‘m going to Arnhem for Easter.
# SENTENCE 73: ​So I’ll call round tomorrow to see if you’re home.
# SENTENCE 74: Bye!
# SENTENCE 75: With my very best wishes, your Piet.
# SENTENCE 76: Brief aan Aletta de Iongh.
# SENTENCE 77: Amsterdam, tussen maandag 19 en vrijdag 23 april 1909.
# SENTENCE 78: Wietse Coppes
# SENTENCE 79: Leo Jansen
# SENTENCE 80: Mondriaan Editieproject
# SENTENCE 81: Nederland
# SENTENCE 82: Otterlo
# SENTENCE 83: Kröller Müller Museum
# SENTENCE 84: KM 120.999
# SENTENCE 85: 19090421y_IONG_1304
# SENTENCE 86: ​
# SENTENCE 87: ​
# SENTENCE 88: ​
# SENTENCE 89: Piet Mondriaan
# SENTENCE 90: tussen maandag 19 en vrijdag 23 april 1909
# SENTENCE 91: Amsterdam[?]
# SENTENCE 92: Aletta de Iongh
# SENTENCE 93: transcriptie: voltooid 21.7.15
# SENTENCE 94: collatie bron: 6.6.16
# SENTENCE 95: tweede collatie: voltooid 5.8.16
# SENTENCE 96: invoer tweede collatie: voltooid 5.8.16
# SENTENCE 97: bespreking eindversie: gb
# SENTENCE 98: markeren annotaties: in bewerking / voltooid
# SENTENCE 99: gereed 17.4.2019
# SENTENCE 100: titel gecontroleerd 12.10.2020

# %% [markdown]
# ## The first letter

# %%
A.pretty(F.otype.s("letter")[0], full=True, withNodes=False)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/1&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303">proeftuin@19090216y_IONG_1303</a></span></div><div class=" children"><div class="contnr c4    " ><div class="lbl c4  " ><span class="nd">letter </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">proeftuin@19090216y_IONG_1303</span></span></span></div><div class="children hor wrap "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">teiHeader </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">fileDesc </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">titleStmt </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">title </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Brief </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">aan </span></span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Aletta </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">de </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Iongh</span></span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">. </span></span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">Amsterdam</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">, </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">16 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">februari</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">, </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">2 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">maart </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">of </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">dinsdag </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">9 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu"><span class=" is_meta">maart </span></span></div></div><di ...

# %% [markdown]
# ## Overlapping divs

# %% [markdown]
# There are overlapping divs!
# Let's find them all.
#
# First the total amount of divs:

# %%
len(F.otype.s("div"))
# Out:
# 93

# %%
query = """
d1:div
&& d2:div

d1 < d2
"""

results = A.search(query)
# Out:
#   0.01s 69 results

# %%
A.table(results, end=2)
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">div</th><th class="tf">div</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090216y_IONG_1303/6&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090216y_IONG_1303:6">proeftuin@19090216y_IONG_1303:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx" ><span class="plain   hlbx" ><span class="txtu"><span class=" is_note">Manuscript</span></span><span class="txtu"><span class=" is_note">.</span></span><span class="txtu"><span class=" is_note"></span></span><span class="break"><br></span><span class="txtu"><span class=" is_note"></span></span><span class="txtu"><span class=" is_note">De </span></span><span class="txtu"><span class=" is_note">brief </span></span><span class="txtu"><span class=" is_note">is </span></span><span class="txtu"><span class=" is_note">geschreven </span></span><span class="txtu"><span class=" is_note">op </span></span><span class="txtu"><span class=" is_note">een </span></span><span class="txtu"><span class=" is_note">dinsdag </span></span><span class="txtu"><span class=" is_note">voorafgaand </span></span><span class="txtu"><span class=" is_note">aan </span></span><span class="txtu"><span class=" is_note">een </span></span><span class="txtu"><span class=" is_note">van </span></span><span class="txtu"><span class=" is_note">de </span></span><span class="txtu"><span class=" is_note">drie </span></span><span class="txtu"><span class=" is_note">woensdagen </span></span><span class="txtu"><span class=" is_note">waarop </span></span><span class="txtu"><span class=" is_note">Richard </span></span><span class="txtu"><span class=" is_note">Buhlig</span></span><span class="txtu"><span class=" is_note"> </span></span><span class="txtu"><span class=" is_note">on </span></span><span class="txtu"><span class=" is_note">1909 </span></span><span class="txtu"><span class=" is_note">in </span></span><span class="txtu"><span class=" is_note">de </span></span><span class="txtu"><span class=" is_note">kleine </span></span><span class="txtu"><span class=" is_note">zaal </span></span><span class="txtu"><span class=" is_note">van </span></span><span class="txtu"><span class=" is_note">het </span></span><span class="txtu"><span class=" is_note">Concertgebouw </span></span><span class="txtu"><span class=" is_note">een </span></span><span class="txtu"><span class=" is_note">concert </span></span><span class="txtu"><span class=" is_note">zou </span></span><span class="txtu"><span class=" is_note">geven</span></span><span class="txtu"><span class=" is_note">: </span></span><span class="txtu"><span class=" is_note">17 </span></span><span class="txtu"><span class=" is_note">februari</span></span><span class="txtu"><span class=" is_note">, </span></span><span class="txtu"><span class=" is_note">3 </span></span><span class="txtu"><span class=" is_note">maart </span></span><span class="txtu"><span class=" is_note">en </span></span><span class="txtu"><span class=" is_note">10 </span></span><span class="txtu"><span class=" is_note">maart</span></span><span class="txtu"><span class=" is_note">. </span></span><span class="txtu"><span class=" is_note">Zie </span></span><span class="txtu"><span class=" is_note">tevens </span></span><span class="txtu"><span class=" is_note">noot </span></span><span class="txtu"><span class=" is_note">1</span></span><span class="txtu"><span class=" is_note">.</span></span><span class="txtu"><span class=" is_note"></span></span><span class="break"><br></span><span class="txtu"><span class=" is_note"></span></span></span><span class="plain  r " ><span class="txtu">​</span></span><span class="txtu"><span class=" is_note">Aletta</span></span><span class="txtu"><span class=" is_note"> </span></span><span class="txtu"><span class=" is_note">werd </span></span><span class="txtu"><span class=" is_note">binnen </span></span><span class="txtu"><span class=" is_ ...

# %%
for (i, s) in enumerate(F.otype.s("sentence")[0:100]):
    print(f"SENTENCE {i + 1}: {T.text(s)}")
# Out:
# SENTENCE 1: Brief aan Aletta de Iongh.
# SENTENCE 2: Amsterdam, dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909.
# SENTENCE 3: Wietse Coppes
# SENTENCE 4: Leo Jansen
# SENTENCE 5: Mondriaan Editieproject
# SENTENCE 6: Nederland
# SENTENCE 7: Otterlo
# SENTENCE 8: Kröller Müller Museum
# SENTENCE 9: KM 123.397
# SENTENCE 10: 19090216y_IONG_1303
# SENTENCE 11: ​
# SENTENCE 12: ​
# SENTENCE 13: ​
# SENTENCE 14: Piet Mondriaan
# SENTENCE 15: dinsdag 16 februari, dinsdag 2 maart of dinsdag 9 maart 1909
# SENTENCE 16: Amsterdam
# SENTENCE 17: Aletta de Iongh
# SENTENCE 18: transcriptie: voltooid 20.7.15
# SENTENCE 19: collatie bron: 6.6.16
# SENTENCE 20: tweede collatie aan het origineel: voltooid 26.11.19
# SENTENCE 21: invoer tweede collatie: voltooid 5.8.16
# SENTENCE 22: bespreking eindversie: gb
# SENTENCE 23: markeren annotaties: in bewerking / voltooid
# SENTENCE 24: gereed 17.4.2019
# SENTENCE 25: titel gecontroleerd 21.09.2020
# SENTENCE 26: personen getagd 12.10.2020
# SENTENCE 27: vertaling ingevoerd 16.2.2021
# SENTENCE 28: codering personen aangepast 16.2.2022
# SENTENCE 29: ​
# ​
# ​
# ​
# SENTENCE 30: Beste Zus,
# ​kom je morgenavond (Woensdag) om kwart voor acht ingang kleine zaal Concert-gebouw,  dan heb ik een plaats voor v.  Buhlig voor je.
# SENTENCE 31: ​En dan kunnen we een andere dan Donderdagmiddag afspreken want dan kan ik niet goed.
# SENTENCE 32: Met vele beste groeten je Piet.
# SENTENCE 33: ​
# Dear Zus,​
# If you come to the entrance to the small auditorium in the Concertgebouw at a quarter to eight tomorrow (Wednesday) evening, I have a ticket for van Buhlig for you.[2] And then we can arrange a time other than Thursday afternoon because I can’t manage that.
# SENTENCE 34: With my very best wishes, your Piet.
# SENTENCE 35: Brief aan Aletta de Iongh.
# SENTENCE 36: Amsterdam, woensdag 7 april 1909.
# SENTENCE 37: Wietse Coppes
# SENTENCE 38: Leo Jansen
# SENTENCE 39: Mondriaan Editieproject
# SENTENCE 40: Nederland
# SENTENCE 41: Otterlo
# SENTENCE 42: Kröller Müller Museum
# SENTENCE 43: KM 122.574
# SENTENCE 44: 19090407y_IONG_1739
# SENTENCE 45: ​
# SENTENCE 46: ​
# SENTENCE 47: ​
# SENTENCE 48: Piet Mondriaan
# SENTENCE 49: woensdag 7 april 1909
# SENTENCE 50: Amsterdam
# SENTENCE 51: Aletta de Iongh
# SENTENCE 52: transcriptie: voltooid 18.8.16
# SENTENCE 53: collatie bron: voltooid 18.8.16
# SENTENCE 54: tweede collatie aan origineel: voltooid 26.11.19
# SENTENCE 55: invoer tweede collatie: gb
# SENTENCE 56: bespreking eindversie: gb
# SENTENCE 57: markeren annotaties: te doen / in bewerking / voltooid
# SENTENCE 58: gereed 17.4.2019
# SENTENCE 59: titel gecontroleerd 15.9.2020
# SENTENCE 60: personen getagd 12.10.2020
# SENTENCE 61: vertaling ingevoerd 16.2.2021
# SENTENCE 62: codering personen aangepast 16.2.2022
# SENTENCE 63: ​
# ​
# ​
# ​
# SENTENCE 64: Lieve Zus,
# neem me niet kwalijk dat ik je zoo'n gekreukte enveloppe zend​, maar ik had geen meer in huis, en ik moest je toch even zeggen dat ik morgen middag helaas in 't museum bij 't ophangen van schilderijen moet zijn, omdat ik in de jury van St Lucas ben.
# SENTENCE 65: ​
# Ik ben er al een groot deel van de week geweest.
# SENTENCE 66: Ik woû je wel graag tusschen 4 - 5 even komen opzoeken, anders zie ik je weer in een week denkelijk niet, want ik ga met de Paaschdagen naar Arnhem.
# SENTENCE 67: ​Ik kom dus morgen even zien of je thuis ben.
# SENTENCE 68: Dag!
# SENTENCE 69: Veel beste groeten je Piet.
# SENTENCE 70: ​
# Dear Zus,
# I’m sorry I’m sending you such a crumpled envelope, ​but I didn’t have any more in the house, and I had to tell you that unfortunately I have to be in the museum tomorrow afternoon when the paintings are hung because I’m on the St Lucas jury.
# SENTENCE 71: ​
# I’ve already been there for a good part of the week.
# SENTENCE 72: I’d like to come and see you between 4 and 5, otherwise I don’t think I’ll see you again in a week, because I ‘m going to Arnhem for Easter.
# SENTENCE 73: ​So I’ll call round tomorrow to see if you’re home.
# SENTENCE 74: Bye!
# SENTENCE 75: With my very best wishes, your Piet.
# SENTENCE 76: Brief aan Aletta de Iongh.
# SENTENCE 77: Amsterdam, tussen maandag 19 en vrijdag 23 april 1909.
# SENTENCE 78: Wietse Coppes
# SENTENCE 79: Leo Jansen
# SENTENCE 80: Mondriaan Editieproject
# SENTENCE 81: Nederland
# SENTENCE 82: Otterlo
# SENTENCE 83: Kröller Müller Museum
# SENTENCE 84: KM 120.999
# SENTENCE 85: 19090421y_IONG_1304
# SENTENCE 86: ​
# SENTENCE 87: ​
# SENTENCE 88: ​
# SENTENCE 89: Piet Mondriaan
# SENTENCE 90: tussen maandag 19 en vrijdag 23 april 1909
# SENTENCE 91: Amsterdam[?]
# SENTENCE 92: Aletta de Iongh
# SENTENCE 93: transcriptie: voltooid 21.7.15
# SENTENCE 94: collatie bron: 6.6.16
# SENTENCE 95: tweede collatie: voltooid 5.8.16
# SENTENCE 96: invoer tweede collatie: voltooid 5.8.16
# SENTENCE 97: bespreking eindversie: gb
# SENTENCE 98: markeren annotaties: in bewerking / voltooid
# SENTENCE 99: gereed 17.4.2019
# SENTENCE 100: titel gecontroleerd 12.10.2020

# %% [markdown]
# ### Notes

# %%
for (i, nn) in enumerate(F.otype.s("note")[4:5]):
    Apre.dm(f"### Note {i + 1}\n\n")
    s1 = L.u(L.d(nn, otype="token")[0], otype="chunk")[0]
    s2 = s1 + 1
    A.pretty(nn, withNodes=True, full=True)
    A.pretty(s1, withNodes=True, full=True)
    A.pretty(s2, withNodes=True, full=True)
# Out:
# ### Note 1
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/6&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739:6">proeftuin@19090407y_IONG_1739:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14641 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">682 </span> <span class="txtu"><span class=" is_note">Manuscript</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">683 </span> <span class="txtu"><span class=" is_note">.</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">684 </span> <span class="txtu"><span class=" is_note"><br></span></span></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090407y_IONG_1739/6&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090407y_IONG_1739:6">proeftuin@19090407y_IONG_1739:6</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk:14004 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">div:14235 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">div:14236 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14641 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">682 </span> <span class="txtu"><span class=" is_note">Manuscript</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">683 </span> <span class="txtu"><span class=" is_note">.</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">684 </span> <span class="txtu"><span class=" is_note"><br></span></span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">note:14642 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">685 </span> <span class="txtu"><span class=" is_note">De </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">686 </span> <span class="txtu"><span class=" is_note">brief </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">687 </span> <span class="txtu"><span class=" is_note">dateert </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">688 </span> <span class="txtu"><span class=" is_note">van </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">689 </span> <span class="txtu"><span class=" is_note">kort </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">690 </span> <span class="txtu"><span class=" is_note">voor </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">691 </span> <span class="txtu"><span class=" is_note">Pasen </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">692 </span> <span class="txtu"><span class=" is_note">1909 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">693 </span> <span class="txtu"><span class=" is_note">(</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">694 </span> <span class="txtu"><span class=" is_note">zie </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">695 </span> <span class="txtu"><span class=" is_note">r. </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">696 </span> <span class="txtu"><span class=" is_note">*</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">697 </span> <span class="txtu"><span class=" is_note">*</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">698 </span> <span class="txtu"><span class=" is_note">*</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">699 </span> <span class="txtu"><span class=" is_note">-</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">700 </span> <span class="txtu"><span class=" is_note">*</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd" ...
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mondriaan/proeftuin/19090421y_IONG_1304/1&amp;version=0.8.1" title="Show this on the website" sec="proeftuin@19090421y_IONG_1304:1">proeftuin@19090421y_IONG_1304:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">chunk:14005 </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">teiHeader:15505 </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">fileDesc:14365 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">titleStmt:15547 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">title:15533 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15638 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1000 </span> <span class="txtu"><span class=" is_meta">Brief </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1001 </span> <span class="txtu"><span class=" is_meta">aan </span></span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">rs:15155 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1002 </span> <span class="txtu"><span class=" is_meta">Aletta </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1003 </span> <span class="txtu"><span class=" is_meta">de </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1004 </span> <span class="txtu"><span class=" is_meta">Iongh</span></span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1005 </span> <span class="txtu"><span class=" is_meta">. </span></span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:15639 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1006 </span> <span class="txtu"><span class=" is_meta">Amsterdam</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1007 </span> <span class="txtu"><span class=" is_meta">, </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1008 </span> <span class="txtu"><span class=" is_meta">tussen </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1009 </span> <span class="txtu"><span class=" is_meta">maandag </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1010 </span> <span class="txtu"><span class=" is_meta">19 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1011 </span> <span class="txtu"><span class=" is_meta">en </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1012 </span> <span class="txtu"><span class=" is_meta">vrijdag </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1013 </span> <span class="txtu"><span class=" is_meta">23 </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1014 </span> <span class="txtu"><span class=" is_meta">april </span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1015 </span> <span class="txtu"><span class=" is_meta">1909</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1016 </span> <span cla ...
