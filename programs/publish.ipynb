# %% [markdown]
# # Publish a new release

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
ORG = "annotation"
REPO = "mondriaan"

# %%
A = use(f"{ORG}/{REPO}:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mondriaan/tf/0.8.8</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.15</a>, <a target="_blank" href="https://github.com/annotation/mondriaan/blob/master/app" title="annotation/mondriaan app">annotation/mondriaan/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
A.publishRelease(3)
# Out:
# [master bcffc39] New minor release
#  1 file changed, 13 insertions(+), 143 deletions(-)
# Latest release = v0.8.7
# New release = v0.8.8
# remote: Resolving deltas: 100% (112/112), completed with 12 local objects.
# To https://github.com/annotation/mondriaan
#  * [new tag]         v0.8.8 -> v0.8.8
# Data to be zipped:
# 	OK       app                      (v0.8.8 c2dd70)     : ~/github/annotation/mondriaan/app
# 	OK       main data                (v0.8.8 c2dd70)     : ~/github/annotation/mondriaan/tf/0.8.8
# 	OK       graphics                 (v0.8.8 c2dd70)     : ~/github/annotation/mondriaan/illustrations
# Writing zip file ...
# Release v0.8.8 created
